# %%
'''import packages'''

import os
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
from matplotlib.colors import ListedColormap
import geopandas as gpd
import pandas as pd
from timeit import default_timer as timer
import sys
import warnings

warnings.filterwarnings('ignore')
start = timer()

# %%
'''import files'''

census = gpd.read_file('data/nz_census/2018-census-individual-part-1-total-new-zealand-by-statistic.shp')
census = census.replace(['C', -999, -998, '0', '..', 'Mainland', 'Inlet', 'Oceanic', 'Island'], 0)
regions = gpd.read_file('data/boundaries/regional_boundaries/REGC2017_HD_Clipped.shp')
city_b = gpd.read_file('data/boundaries/city/UA2017_HD_Clipped.shp')
suburb_b = gpd.read_file('data/boundaries/suburb/TASUB2017_HD_Clipped.shp')
'''census_2 = gpd.read_file('data/nz_census/2018-census-individual-part-2-total-new-zealand-by-statistic.shp')
census_3a = gpd.read_file('data/nz_census/2018-census-individual-part-3a-total-new-zealand-by-statisti.shp')
census_3b = gpd.read_file('data/nz_census/2018-census-individual-part-3b-total-new-zealand-by-statisti.shp')

census = census.merge(census_2, on='SA12018_V1')
census = census.merge(census_3a, on='SA12018_V1')
census = census.merge(census_3b, on='SA12018_V1')'''
# Out:
# "census_2 = gpd.read_file('data/nz_census/2018-census-individual-part-2-total-new-zealand-by-statistic.shp')\ncensus_3a = gpd.read_file('data/nz_census/2018-census-individual-part-3a-total-new-zealand-by-statisti.shp')\ncensus_3b = gpd.read_file('data/nz_census/2018-census-individual-part-3b-total-new-zealand-by-statisti.shp')\n\ncensus = census.merge(census_2, on='SA12018_V1')\ncensus = census.merge(census_3a, on='SA12018_V1')\ncensus = census.merge(census_3b, on='SA12018_V1')"

# %%
#dictionaries no slr

'''nz dict

nz_area = 
nz_total = gpd.clip(census,nz_area)
nz_total = nz_total.sum()
nz_noslr_dict = {'nz': nz_total}'''

'''islands dict
northisland_area = 
northisland_total = gpd.clip(census,northisland_area)
northisland_total = northisland_total.sum()

southisland_area = 
southisland_total = gpd.clip(census,southisland_area)
southisland_total = southisland_total.sum()
island_noslr_dict = {'north island': northisland_total, 'south island': southisland_total}'''

'''regional dict'''
otago_area= regions.iloc[11,4]
otago_total = gpd.clip(census,otago_area)
otago_total = otago_total.sum()

southland_area= regions.iloc[12,4]
southland_total = gpd.clip(census,southland_area)
southland_total = southland_total.sum()

regional_noslr_dict = {'southland' : southland_total, 'otago' : otago_total}

'''city dict'''

'''auck_noslr = gpd.read_file('results/clipped_results/city_noslr/a.csv')
welly_noslr = gpd.read_file('results/clipped_results/city_noslr/welly.csv')
chch_noslr = gpd.read_file('results/clipped_results/city_noslr/chch.csv')
dun_noslr = gpd.read_file('results/clipped_results/city_noslr/dun.csv')
ta_noslr = gpd.read_file('results/clipped_results/city_noslr/tauranga.csv')
city_noslr_dict = {'auckland' : auck_noslr, 'wellington' : welly_noslr, 'christchurch' : chch_noslr, 'dunedin' : dun_noslr, 'tauranga' : ta_noslr}
city_names = ['auckland', 'wellington', 'christchurch', 'dunedin', 'tauranga']
for i in range(1, 5, 1):
    city_name = city_names[i]
    city_noslr_dict[cityname].sum()'''
    

'''auck_b = regions.iloc[1,4]
auck_clip = gpd.clip(census, auck_b)
auck_clip.to_csv('results/city_noslr/auck.csv')
'''
'''welly_b = city_b.iloc[19,4]
welly_clip = gpd.clip(census, welly_b)'''

'''chch_b = city_b.iloc[21,4]
chch_clip = gpd.clip(census, chch_b)'''

'''dun_b = city_b.iloc[22,4]
dun_clip = gpd.clip(census, dun_b)
dun_clip.to_csv('results/city_noslr/dun.csv')'''

'''ta_b = city_b.iloc[8,4]
ta_clip = gpd.clip(census, ta_b)
ta_clip.to_csv('results/city_noslr/tauranga.csv')'''
                           

'''chch sub no slr'''

'''chchsub_noslr_dict = {}
for i in range(0, 2, 1):
    no = i + 82
    key = suburb_b.iloc[no, 1]
    info = gpd.read_file('results/clipped_results/sub_noslr/' + key + '.csv')
    chchsub_noslr_dict.update({key : info}'''

# %%
'''slr cities'''

'''census = gpd.read_file('data/nz_census/2018-census-individual-part-1-total-new-zealand-by-statistic.shp')
census = census.replace(['C', -999, -998, '0', '..', 'Mainland', 'Inlet', 'Oceanic', 'Island'], 0)
regions = gpd.read_file('data/boundaries/regional_boundaries/REGC2017_HD_Clipped.shp')
city_b = gpd.read_file('data/boundaries/city/UA2017_HD_Clipped.shp')
suburb_b = gpd.read_file('data/boundaries/suburb/TASUB2017_HD_Clipped.shp')

auck_b = regions.iloc[1,4]
welly_b = city_b.iloc[19,4]
chch_b = city_b.iloc[21,4]
dun_b = city_b.iloc[22,4]
ta_b = city_b.iloc[8,4]

city_area_dict = {'auckland' : auck_b, 'wellington' : welly_b, 'christchurch' : chch_b, 'dunedin' : dun_b, 'tauranga' : ta_b}
region_names = ['Auckland', 'Wellington', 'Canterbury', 'Otago', 'BoP']
city_names = ['auckland', 'wellington', 'christchurch', 'dunedin', 'tauranga']
regions_names_ab = ['akl', 'wlg', 'cant', 'Otago', 'bop']

for i in range(0, 1, 1):
    city_name = city_names[i]
    region_name = region_names[i]
    region_name_ab = regions_names_ab[i]
    for eslr in range(0,160,10):
        slr_data = gpd.read_file('data/clipped_census/' + region_name + '/' + region_name_ab + '_aep1pct_{}.shp'.format(eslr))
        area_data = city_area_dict[city_name]
        clipped_data = gpd.clip(slr_data, area_data)
        clipped_data.to_csv('results/city_slr/' + city_name + '_{}.csv'.format(eslr))'''

# %%
#dictionaries slr 

'''nz dict
nz_dict = {}
for eslr in range(0,160,10):
    slr_data = gpd.read_file('results/nz_slr/nz_slr_{}.shp'.format(eslr))
    slr_data = slr_data.sum()
    nz_dict.update({'slr_{}'.format(eslr) : slr_data})'''
    
'''islands dict
island_dict = {}
island_names  = ['north', 'south'] 
for i in range(0,2,1):
        island_name = island_names[i]
        slr_dict = {}
        for eslr in range(0,160,10):
            slr_data = gpd.read_file('results/islands_slr/' + island_name + '_slr_{}.csv'.format(eslr))
            slr_data = slr_data.sum()
            slr_dict.update({'slr_{}'.format(eslr) : slr_data}) 
        island_dict.update({island_name : slr_dict})'''

'''regional dict'''
regional_dict = {}
rc_names  = ['southland', 'otago'] 
rc_names_abrv = ['Southland', 'Otago']
for rc in range(0,2,1):
        regional_name = rc_names[rc]
        regional_name_abrv = rc_names_abrv[rc]
        slr_dict = {}
        for eslr in range(0,160,10):
            slr_data = gpd.read_file('data/clipped_census/'+ regional_name + '/' + regional_name_abrv + '_aep1pct_{}.shp'.format(eslr))
            slr_dict.update({'slr_{}'.format(eslr) : slr_data}) 
        regional_dict.update({regional_name : slr_dict})
        
'''city dict'''
'''city_dict = {}
for eslr in range(0,160,10):
    slr_data = gpd.read_file('data/clipped_census/regional/canterbury/nz_aep1pct_{}.shp'.format(eslr))
    area_data = gpd.read_file('data/results/nz/nz_noslr_{}.shp'.format(eslr))
    slr_data = gdp.clip(census, island_area)
    city_dict.update({'slr_{}'.format(eslr) : slr_data})'''

'''suburb dict'''
'''chchsub_dict = {}
for i in range(0, 15, 1):
    no = i + 82
    key = suburb_b.iloc[no, 1]
    area = chchsub_area_dict[key] 
    slr_dict = {}
    for eslr in range(0, 160, 10):
        slr_data = gpd.read_file('data/clipped_census/regional/canterbury/canterbury_aep1pct_{}.shp'.format(eslr))
        sub_clip = gpd.clip(slr_data, area)
        slr_dict.update({'slr_{}'.format(eslr) : slr_data}) 
    chch_sub_dict.update({key : slr_dict})'''

# %%
''' general info'''

slr = []
for i in range(0, 160, 10):
    slr.append(i)
    
slr_str = []
for i in range(0, 160, 10):
    slr_str.append(str(i) + 'm')
    
years = [2006, 2013, 2018]

'''rc_names  = ['northland', 'auckland', 'waikato', 'bay_of_plenty', 'gisborne','hawkes_bay','taranaki','manawatu_wanganui', 'wellington', 'west_coast','canterbury','otago','southland','tasman','nelson','marlborough']  
'''

# %%
'''sub_names = []

for i in range(0, 16, 1):
    sub = sub_names[i]
    ''''''collate relevent data''''''
    v_maori_decent_06 = [chchsub_dict[sub]['slr_{}'.format(i)]['C06_Maori_'] for i in range(0,160,10)]
    v_maori_decent_13 = [chchsub_dict[sub]['slr_{}'.format(i)]['C13_Maori_'] for i in range(0,160,10)]
    v_maori_decent_18 = [chchsub_dict[sub]['slr_{}'.format(i)]['C18_Maori_'] for i in range(0,160,10)]
    v_no_maori_decent_06 = [chchsub_dict[sub]['slr_{}'.format(i)]['C06_Maor_1'] for i in range(0,160,10)]
    v_no_maori_decent_13 = [chchsub_dict[sub]['slr_{}'.format(i)]['C13_Maor_1'] for i in range(0,160,10)]
    v_no_maori_decent_18 = [chchsub_dict[sub]['slr_{}'.format(i)]['C18_Maor_1'] for i in range(0,160,10)]
    r_maori_decent_06 = [chchsub_dict[rc]['C06_Maori_'] for i in range(0, 160, 10)]
    r_maori_decent_13 = [chchsub_dict[rc]['C13_Maori_'] for i in range(0, 160, 10)]
    r_maori_decent_18 = [chchsub_dict[rc]['C18_Maori_'] for i in range(0, 160, 10)]
    r_no_maori_decent_06 = [chchsub_dict[rc]['C06_Maor_1'] for i in range(0, 160, 10)]
    r_no_maori_decent_13 = [chchsub_dict[rc]['C13_Maor_1'] for i in range(0, 160, 10)]
    r_no_maori_decent_18 = [chchsub_dict[rc]['C18_Maor_1'] for i in range(0, 160, 10)]
    po_maori_decent_06 = [x/(y/100) for x, y in zip(v_maori_decent_06, r_maori_decent_06)]
    po_maori_decent_13 = [x/(y/100) for x, y in zip(v_maori_decent_13, r_maori_decent_13)]
    po_maori_decent_18 = [x/(y/100) for x, y in zip(v_maori_decent_18, r_maori_decent_18)]
    po_no_maori_decent_06 = [x/(y/100) for x, y in zip(v_no_maori_decent_06, r_no_maori_decent_06)]
    po_no_maori_decent_13 = [x/(y/100) for x, y in zip(v_no_maori_decent_13, r_no_maori_decent_13)]
    po_no_maori_decent_18 = [x/(y/100) for x, y in zip(v_no_maori_decent_18, r_no_maori_decent_18)]
    
    ''''''maori_decent''''''
    v_maori_decent_dict_time = {}
    p_maori_decent_dict_time = {}
    pc_maori_decent_dict_time = {}
    po_maori_decent_dict_time = {}
    
    if rc == 'otago':
        rc = 'otago   '
    
    v_maori_decent_df = pd.DataFrame({'years' : years})
    v_maori_decent_df.columns.name = rc
    p_maori_decent_df = pd.DataFrame({'years' : years})
    p_maori_decent_df.columns.name = rc
    pc_maori_decent_df = pd.DataFrame({'years' : years})
    pc_maori_decent_df.columns.name = rc
    po_maori_decent_df = pd.DataFrame({'years' : years})
    po_maori_decent_df.columns.name = rc
    
    for i in range(0, 16, 1):
        v_maori_decent_time = []
        v_maori_decent_time.append(v_maori_decent_06[i])
        v_maori_decent_time.append(v_maori_decent_13[i])
        v_maori_decent_time.append(v_maori_decent_18[i])
        v_maori_decent_dict_time.update({'slr_{}0'.format(i) : v_maori_decent_time})
        p_maori_decent_time = []
        p_maori_decent_time.append(p_maori_decent_06[i])
        p_maori_decent_time.append(p_maori_decent_13[i])
        p_maori_decent_time.append(p_maori_decent_18[i])
        p_maori_decent_dict_time.update({'slr_{}0'.format(i) : p_maori_decent_time})
        pc_maori_decent_time = []
        pc_maori_decent_time.append(pc_maori_decent_06[i])
        pc_maori_decent_time.append(pc_maori_decent_13[i])
        pc_maori_decent_time.append(pc_maori_decent_18[i])
        pc_maori_decent_dict_time.update({'slr_{}0'.format(i) : pc_maori_decent_time})
        po_maori_decent_time = []
        po_maori_decent_time.append(po_maori_decent_06[i])
        po_maori_decent_time.append(po_maori_decent_13[i])
        po_maori_decent_time.append(po_maori_decent_18[i])
        po_maori_decent_dict_time.update({'slr_{}0'.format(i) : po_maori_decent_time})
        if i == 0 or i == 5 or i == 10:
            v_maori_decent_df['slr_{}0'.format(i)] = v_maori_decent_time
            po_maori_decent_df['slr_{}0'.format(i)] = [round(num, 1) for num in po_maori_decent_time]'''

# %%
#gender slr progression

rc_names  = ['southland', 'otago'] 
rc_names_abrv = ['Southland', 'Otago'] 


for i in range(0, 2, 1):
    rc = rc_names[i]
    print(rc)
    '''collate relevent data'''
    v_female_06 = [regional_dict[rc]['slr_{}'.format(i)]['C06_Sex_Fe'] for i in range(0,160,10)]
    v_female_13 = [regional_dict[rc]['slr_{}'.format(i)]['C13_Sex_Fe'] for i in range(0,160,10)]
    v_female_18 = [regional_dict[rc]['slr_{}'.format(i)]['C18_Sex_Fe'] for i in range(0,160,10)]
    v_male_06 = [regional_dict[rc]['slr_{}'.format(i)]['C06_Sex_Ma'] for i in range(0,160,10)]
    v_male_13 = [regional_dict[rc]['slr_{}'.format(i)]['C13_Sex_Ma'] for i in range(0,160,10)]
    v_male_18 = [regional_dict[rc]['slr_{}'.format(i)]['C18_Sex_Ma'] for i in range(0,160,10)]
    p_female_06 = [((x/y)*100) for x, y in zip(v_female_06, total_06)]
    p_female_13 = [((x/y)*100) for x, y in zip(v_female_13, total_13)]
    p_female_18 = [((x/y)*100) for x, y in zip(v_female_18, total_18)]
    p_male_06 = [((x/y)*100) for x, y in zip(v_male_06, total_06)]
    p_male_13 = [((x/y)*100) for x, y in zip(v_male_13, total_13)]
    p_male_18 = [((x/y)*100) for x, y in zip(v_male_18, total_18)]
    r_female_06 = [regional_noslr_dict[rc]['C06_Sex_Fe'] for i in range(0, 160, 10)]
    r_female_13 = [regional_noslr_dict[rc]['C13_Sex_Fe'] for i in range(0, 160, 10)]
    r_female_18 = [regional_noslr_dict[rc]['C18_Sex_Fe'] for i in range(0, 160, 10)]
    r_male_06 = [regional_noslr_dict[rc]['C06_Sex_Ma'] for i in range(0, 160, 10)]
    r_male_13 = [regional_noslr_dict[rc]['C13_Sex_Ma'] for i in range(0, 160, 10)]
    r_male_18 = [regional_noslr_dict[rc]['C18_Sex_Ma'] for i in range(0, 160, 10)]
    pc_female_06 = [z-(x/((x+y)/100)) for x, y, z in zip(r_female_06, r_male_06, p_female_06)]
    pc_female_13 = [z-(x/((x+y)/100)) for x, y, z in zip(r_female_13, r_male_13, p_female_13)]
    pc_female_18 = [z-(x/((x+y)/100)) for x, y, z in zip(r_female_18, r_male_18, p_female_18)]
    pc_male_06 = [z-(x/((x+y)/100)) for x, y, z in zip(r_male_06, r_male_06, p_male_06)]
    pc_male_13 = [z-(x/((x+y)/100)) for x, y, z in zip(r_male_13, r_male_13, p_male_13)]
    pc_male_18 = [z-(x/((x+y)/100)) for x, y, z in zip(r_male_18, r_male_18, p_male_18)]
    po_female_06 = [x/(y/100) for x, y in zip(v_female_06, r_female_06)]
    po_female_13 = [x/(y/100) for x, y in zip(v_female_13, r_female_13)]
    po_female_18 = [x/(y/100) for x, y in zip(v_female_18, r_female_18)]
    po_male_06 = [x/(y/100) for x, y in zip(v_male_06, r_male_06)]
    po_male_13 = [x/(y/100) for x, y in zip(v_male_13, r_male_13)]
    po_male_18 = [x/(y/100) for x, y in zip(v_male_18, r_male_18)]

    '''make all this plotting useful and orderly'''   
    title_offset = 1.03
    male_ad_offset = (115, 0)
    
    '''creating values'''
    slr_short = [0, 50, 100, 150]
    vs_fem_df_06 = pd.DataFrame({'slr' : slr_short})
    vs_fem_df_06.columns.name = rc
    vs_fem_df_13 = pd.DataFrame({})
    vs_fem_df_13.columns.name = rc
    vs_fem_df_18 = pd.DataFrame({})
    vs_fem_df_18.columns.name = rc
    vs_mal_df_06 = pd.DataFrame({'slr' : slr_short})
    vs_mal_df_06.columns.name = rc
    vs_mal_df_13 = pd.DataFrame({})
    vs_mal_df_13.columns.name = rc
    vs_mal_df_18 = pd.DataFrame({})
    vs_mal_df_18.columns.name = rc
    pos_fem_df_06 = pd.DataFrame({})
    pos_fem_df_06.columns.name = rc
    pos_fem_df_13 = pd.DataFrame({})
    pos_fem_df_13.columns.name = rc
    pos_fem_df_18 = pd.DataFrame({})
    pos_fem_df_18.columns.name = rc
    pos_mal_df_06 = pd.DataFrame({})
    pos_mal_df_06.columns.name = rc
    pos_mal_df_13 = pd.DataFrame({})
    pos_mal_df_13.columns.name = rc
    pos_mal_df_18 = pd.DataFrame({})
    pos_mal_df_18.columns.name = rc
    
    vs_fem_l1_06 = []
    vs_fem_l1_13 = []
    vs_fem_l1_18 = []
    pos_fem_l1_06 = []
    pos_fem_l1_13 = []
    pos_fem_l1_18 = []
    vs_mal_l1_06 = []
    vs_mal_l1_13 = []
    vs_mal_l1_18 = []
    pos_mal_l1_06 = []
    pos_mal_l1_13 = []
    pos_mal_l1_18 = []
    
    for i in range(0, 16, 5):
        vs_fem_l2_06 = v_female_06[i]
        vs_fem_l1_06.append(vs_fem_l2_06)
        vs_fem_l2_13 = v_female_13[i]
        vs_fem_l1_13.append(vs_fem_l2_13)
        vs_fem_l2_18 = v_female_18[i]
        vs_fem_l1_18.append(vs_fem_l2_18)
        pos_fem_l2_06 = po_female_06[i]
        pos_fem_l1_06.append(pos_fem_l2_06)
        pos_fem_l2_13 = po_female_13[i]
        pos_fem_l1_13.append(pos_fem_l2_13)
        pos_fem_l2_18 = po_female_18[i]
        pos_fem_l1_18.append(pos_fem_l2_18)
        vs_mal_l2_06 = v_male_06[i]
        vs_mal_l1_06.append(vs_mal_l2_06)
        vs_mal_l2_13 = v_male_13[i]
        vs_mal_l1_13.append(vs_mal_l2_13)
        vs_mal_l2_18 = v_male_18[i]
        vs_mal_l1_18.append(vs_mal_l2_18)
        pos_mal_l2_06 = po_male_06[i]
        pos_mal_l1_06.append(pos_mal_l2_06)
        pos_mal_l2_13 = po_male_13[i]
        pos_mal_l1_13.append(pos_mal_l2_13)
        pos_mal_l2_18 = po_male_18[i]
        pos_mal_l1_18.append(pos_mal_l2_18)
    vs_fem_df_06['2006'] = [round(num, 1) for num in vs_fem_l1_06]
    vs_fem_df_13['2013'] = [round(num, 1) for num in vs_fem_l1_13]
    vs_fem_df_18['2018'] = [round(num, 1) for num in vs_fem_l1_18]
    pos_fem_df_06['2006'] = [round(num, 1) for num in pos_fem_l1_06]
    pos_fem_df_13['2013'] = [round(num, 1) for num in pos_fem_l1_13]
    pos_fem_df_18['2018'] = [round(num, 1) for num in pos_fem_l1_18]
    vs_mal_df_06['2006'] = [round(num, 1) for num in vs_mal_l1_06]
    vs_mal_df_13['2013'] = [round(num, 1) for num in vs_mal_l1_13]
    vs_mal_df_18['2018'] = [round(num, 1) for num in vs_mal_l1_18]
    pos_mal_df_06['2006'] = [round(num, 1) for num in pos_mal_l1_06]
    pos_mal_df_13['2013'] = [round(num, 1) for num in pos_mal_l1_13]
    pos_mal_df_18['2018'] = [round(num, 1) for num in pos_mal_l1_18]
    
    vs_fem_df_all = pd.concat([vs_fem_df_06, vs_fem_df_13, vs_fem_df_18], axis=1)
    pos_fem_df_all = pd.concat([pos_fem_df_06, pos_fem_df_13, pos_fem_df_18], axis=1)
    vs_mal_df_all = pd.concat([vs_mal_df_06, vs_mal_df_13, vs_mal_df_18], axis=1)
    pos_mal_df_all = pd.concat([pos_mal_df_06, pos_mal_df_13, pos_mal_df_18], axis=1)
    
    '''excel not working '''
    fem_all_df = pd.concat([vs_fem_df_all, pos_fem_df_all], axis=1)
    fem_all_df.loc[-1] = [rc, '', '', '', '', '', '']  
    fem_all_df.index = all_df.index + 1  
    fem_all_df.sort_index(inplace=True) 
    fem_all_df.to_csv('results/gender/female.csv', mode='a')
    print(fem_all_df)
    
    mal_all_df = pd.concat([vs_mal_df_all, pos_mal_df_all], axis=1)
    mal_all_df.loc[-1] = [rc, '', '', '', '', '', '']  
    mal_all_df.index = all_df.index + 1  
    mal_all_df.sort_index(inplace=True) 
    mal_all_df.to_csv('results/gender/male.csv', mode='a')
    print(mal_all_df)
    
    
    '''plot slr values'''
    plt.plot(slr, v_female_06, label="female 06", color="c")
    plt.annotate('female 2006', (150, v_female_06[15]), textcoords="offset points", xytext=(40,5), fontsize=11, ha='center', color='c')
    plt.plot(slr, v_female_13, label="female 13", color="c")
    plt.annotate('female 2013', (150, v_female_13[15]), textcoords="offset points", xytext=(40,5), fontsize=11, ha='center', color='c')
    plt.plot(slr, v_female_18, label="female 18", color="c")
    plt.annotate('female 2018', (150, v_female_18[15]), textcoords="offset points", xytext=(40,5), fontsize=11, ha='center', color='c')
    plt.plot(slr, v_male_06, label="male 06", color="pink")
    plt.annotate('male 2006', (150, v_male_06[15]), textcoords="offset points", xytext=male_ad_offset, fontsize=11, ha='center', color='pink')
    plt.plot(slr, v_male_13, label="male 13", color="pink")
    plt.annotate('male 2013', (150, v_male_13[15]), textcoords="offset points", xytext=male_ad_offset, fontsize=11, ha='center', color='pink')
    plt.plot(slr, v_male_18, label="male 18", color="pink")
    plt.annotate('male 2018', (150, v_male_18[15]), textcoords="offset points", xytext=male_ad_offset, fontsize=11, ha='center', color='pink')
    plt.xlabel('Sea level rise (cm)')
    plt.ylabel('Number of people exposed')
    plt.title('Number of each gender exposed as sea level rise increase, relative to time', y=title_offset)
    ax = plt.subplot(111)
    ax.spines["right"].set_visible(False)
    ax.spines["top"].set_visible(False)
    plt.tight_layout()
    plt.savefig('results/gender/'+ rc + '_v_gender.jpg')
    plt.show()
    
    ''' plot slr percentages '''
    plt.plot(slr, p_female_06, label="female 06", color="c")
    plt.annotate('female 2006', (150, p_female_06[15]), textcoords="offset points", xytext=(40,5), fontsize=11, ha='center', color='c')
    plt.plot(slr, p_female_13, label="female 13", color="c")
    plt.annotate('female 2013', (150, p_female_13[15]), textcoords="offset points", xytext=(40,5), fontsize=11, ha='center', color='c')
    plt.plot(slr, p_female_18, label="female 18", color="c")
    plt.annotate('female 2018', (150, p_female_18[15]), textcoords="offset points", xytext=(40,5), fontsize=11, ha='center', color='c')
    plt.plot(slr, p_male_06, label="male 06", color="pink")
    plt.annotate('male 2006', (150, p_male_06[15]), textcoords="offset points", xytext=male_ad_offset, fontsize=11, ha='center', color='pink')
    plt.plot(slr, p_male_13, label="male 13", color="pink")
    plt.annotate('male 2013', (150, p_male_13[15]), textcoords="offset points", xytext=male_ad_offset, fontsize=11, ha='center', color='pink')
    plt.plot(slr, p_male_18, label="male 18", color="pink")
    plt.annotate('male 2018', (150, p_male_18[15]), textcoords="offset points", xytext=male_ad_offset, fontsize=11, ha='center', color='pink')
    plt.xlabel('Sea level rise (cm)')
    plt.ylabel('Percentage of people exposed (%)')
    plt.title('Percentage of each gender exposed as sea level rise increase, relative to time', y=title_offset)
    ax = plt.subplot(111)
    ax.spines["right"].set_visible(False)
    ax.spines["top"].set_visible(False)
    plt.tight_layout()
    plt.savefig('results/gender/'+ rc + '_p_gender.jpg')
    plt.show()
    
    '''plot slr percentage change '''
    plt.plot(slr, pc_female_06, label="female 06", color="c")
    plt.annotate('female 2006', (150, pc_female_06[15]), textcoords="offset points", xytext=(40,5), fontsize=11, ha='center', color='c')
    plt.plot(slr, pc_female_13, label="female 13", color="c")
    plt.annotate('female 2013', (150, pc_female_13[15]), textcoords="offset points", xytext=(40,5), fontsize=11, ha='center', color='c')
    plt.plot(slr, pc_female_18, label="female 18", color="c")
    plt.annotate('female 2018', (150, pc_female_18[15]), textcoords="offset points", xytext=(40,5), fontsize=11, ha='center', color='c')
    plt.plot(slr, pc_male_06, label="male 06", color="pink")
    plt.annotate('male 2006', (150, pc_male_06[15]), textcoords="offset points", xytext=male_ad_offset, fontsize=11, ha='center', color='pink')
    plt.plot(slr, pc_male_13, label="male 13", color="pink")
    plt.annotate('male 2013', (150, pc_male_13[15]), textcoords="offset points", xytext=male_ad_offset, fontsize=11, ha='center', color='pink')
    plt.plot(slr, pc_male_18, label="male 18", color="pink")
    plt.annotate('male 2018', (150, pc_male_18[15]), textcoords="offset points", xytext=male_ad_offset, fontsize=11, ha='center', color='pink')
    plt.xlabel('Sea level rise (cm)')
    plt.ylabel('Percentage chnage of people exposed (%)')
    plt.title('Percentage change of each gender exposed as sea level rise increase, relative to time', y=title_offset)
    ax = plt.subplot(111)
    ax.spines["right"].set_visible(False)
    ax.spines["top"].set_visible(False)
    plt.tight_layout()
    plt.savefig('results/gender/'+ rc + '_pc_gender.jpg')
    plt.show()
    
    
    '''plot slr percentage overall '''
    plt.plot(slr, po_female_06, label="female 06", color="c")
    plt.annotate('female 2006', (150, po_female_06[15]), textcoords="offset points", xytext=(40,5), fontsize=11, ha='center', color='c')
    plt.plot(slr, po_female_13, label="female 13", color="c")
    plt.annotate('female 2013', (150, po_female_13[15]), textcoords="offset points", xytext=(40,5), fontsize=11, ha='center', color='c')
    plt.plot(slr, po_female_18, label="female 18", color="c")
    plt.annotate('female 2018', (150, po_female_18[15]), textcoords="offset points", xytext=(40,5), fontsize=11, ha='center', color='c')
    plt.plot(slr, po_male_06, label="male 06", color="pink")
    plt.annotate('male 2006', (150, po_male_06[15]), textcoords="offset points", xytext=male_ad_offset, fontsize=11, ha='center', color='pink')
    plt.plot(slr, po_male_13, label="male 13", color="pink")
    plt.annotate('male 2013', (150, po_male_13[15]), textcoords="offset points", xytext=male_ad_offset, fontsize=11, ha='center', color='pink')
    plt.plot(slr, po_male_18, label="male 18", color="pink")
    plt.annotate('male 2018', (150, po_male_18[15]), textcoords="offset points", xytext=male_ad_offset, fontsize=11, ha='center', color='pink')
    plt.xlabel('Sea level rise (cm)')
    plt.ylabel('Percentage of people exposed (%)')
    plt.title('Percentage of each gender exposed as sea level rise increase, relative to time', y=title_offset)
    ax = plt.subplot(111)
    ax.spines["right"].set_visible(False)
    ax.spines["top"].set_visible(False)
    plt.tight_layout()
    plt.savefig('results/gender/'+ rc + '_po_gender.jpg')
    plt.show()

# %%
'''nz born or overseas'''

#slr progression - nz born or overseas 

rc_names  = ['southland', 'otago'] 
rc_names_abrv = ['Southland', 'Otago'] 


for i in range(0, 2, 1):
    rc = rc_names[i]
    print(rc)
    '''collate relevent data'''
    v_nz_born_06 = [regional_dict[rc]['slr_{}'.format(i)]['C06_Birthp'] for i in range(0,160,10)]
    v_nz_born_13 = [regional_dict[rc]['slr_{}'.format(i)]['C13_Birthp'] for i in range(0,160,10)]
    v_nz_born_18 = [regional_dict[rc]['slr_{}'.format(i)]['C18_Birthp'] for i in range(0,160,10)]
    v_overseas_born_06 = [regional_dict[rc]['slr_{}'.format(i)]['C06_Birt_1'] for i in range(0,160,10)]
    v_overseas_born_13 = [regional_dict[rc]['slr_{}'.format(i)]['C13_Birt_1'] for i in range(0,160,10)]
    v_overseas_born_18 = [regional_dict[rc]['slr_{}'.format(i)]['C18_Birt_1'] for i in range(0,160,10)]
    total_06 = [sum(x) for x in zip(v_nz_born_06, v_overseas_born_06)]
    total_13 = [sum(x) for x in zip(v_nz_born_13, v_overseas_born_13)]
    total_18 = [sum(x) for x in zip(v_nz_born_18, v_overseas_born_18)]
    p_nz_born_06 = [((x/y)*100) for x, y in zip(v_nz_born_06, total_06)]
    p_nz_born_13 = [((x/y)*100) for x, y in zip(v_nz_born_13, total_13)]
    p_nz_born_18 = [((x/y)*100) for x, y in zip(v_nz_born_18, total_18)]
    p_overseas_born_06 = [((x/y)*100) for x, y in zip(v_overseas_born_06, total_06)]
    p_overseas_born_13 = [((x/y)*100) for x, y in zip(v_overseas_born_13, total_13)]
    p_overseas_born_18 = [((x/y)*100) for x, y in zip(v_overseas_born_18, total_18)]
    r_nz_born_06 = [regional_noslr_dict[rc]['C06_Birthp'] for i in range(0, 160, 10)]
    r_nz_born_13 = [regional_noslr_dict[rc]['C13_Birthp'] for i in range(0, 160, 10)]
    r_nz_born_18 = [regional_noslr_dict[rc]['C18_Birthp'] for i in range(0, 160, 10)]
    r_overseas_born_06 = [regional_noslr_dict[rc]['C06_Birt_1'] for i in range(0, 160, 10)]
    r_overseas_born_13 = [regional_noslr_dict[rc]['C13_Birt_1'] for i in range(0, 160, 10)]
    r_overseas_born_18 = [regional_noslr_dict[rc]['C18_Birt_1'] for i in range(0, 160, 10)]
    pc_nz_born_06 = [z-(x/((x+y)/100)) for x, y, z in zip(r_nz_born_06, r_overseas_born_06, p_nz_born_06)]
    pc_nz_born_13 = [z-(x/((x+y)/100)) for x, y, z in zip(r_nz_born_13, r_overseas_born_13, p_nz_born_13)]
    pc_nz_born_18 = [z-(x/((x+y)/100)) for x, y, z in zip(r_nz_born_18, r_overseas_born_18, p_nz_born_18)]
    pc_overseas_born_06 = [z-(x/((x+y)/100)) for x, y, z in zip(r_overseas_born_06, r_overseas_born_06, p_overseas_born_06)]
    pc_overseas_born_13 = [z-(x/((x+y)/100)) for x, y, z in zip(r_overseas_born_13, r_overseas_born_13, p_overseas_born_13)]
    pc_overseas_born_18 = [z-(x/((x+y)/100)) for x, y, z in zip(r_overseas_born_18, r_overseas_born_18, p_overseas_born_18)]
    po_nz_born_06 = [x/(y/100) for x, y in zip(v_nz_born_06, r_nz_born_06)]
    po_nz_born_13 = [x/(y/100) for x, y in zip(v_nz_born_13, r_nz_born_13)]
    po_nz_born_18 = [x/(y/100) for x, y in zip(v_nz_born_18, r_nz_born_18)]
    po_overseas_born_06 = [x/(y/100) for x, y in zip(v_overseas_born_06, r_overseas_born_06)]
    po_overseas_born_13 = [x/(y/100) for x, y in zip(v_overseas_born_13, r_overseas_born_13)]
    po_overseas_born_18 = [x/(y/100) for x, y in zip(v_overseas_born_18, r_overseas_born_18)]

    '''make all this plotting useful and orderly'''   
    title_offset = 1.03
    overseas_born_ad_offset = (115, 0)
    
    '''creating values'''
    slr_short = [0, 50, 100, 150]
    vs_nz_df_06 = pd.DataFrame({'slr' : slr_short})
    vs_nz_df_06.columns.name = rc
    vs_nz_df_13 = pd.DataFrame({'slr' : slr_short})
    vs_nz_df_13.columns.name = rc
    vs_nz_df_18 = pd.DataFrame({'slr' : slr_short})
    vs_nz_df_18.columns.name = rc
    vs_overseas_df_06 = pd.DataFrame({'slr' : slr_short})
    vs_overseas_df_06.columns.name = rc
    vs_overseas_df_13 = pd.DataFrame({'slr' : slr_short})
    vs_overseas_df_13.columns.name = rc
    vs_overseas_df_18 = pd.DataFrame({'slr' : slr_short})
    vs_overseas_df_18.columns.name = rc
    pos_nz_df_06 = pd.DataFrame({'slr' : slr_short})
    pos_nz_df_06.columns.name = rc
    pos_nz_df_13 = pd.DataFrame({'slr' : slr_short})
    pos_nz_df_13.columns.name = rc
    pos_nz_df_18 = pd.DataFrame({'slr' : slr_short})
    pos_nz_df_18.columns.name = rc
    pos_overseas_df_06 = pd.DataFrame({'slr' : slr_short})
    pos_overseas_df_06.columns.name = rc
    pos_overseas_df_13 = pd.DataFrame({'slr' : slr_short})
    pos_overseas_df_13.columns.name = rc
    pos_overseas_df_18 = pd.DataFrame({'slr' : slr_short})
    pos_overseas_df_18.columns.name = rc
    
    vs_nz_l1_06 = []
    vs_nz_l1_13 = []
    vs_nz_l1_18 = []
    pos_nz_l1_06 = []
    pos_nz_l1_13 = []
    pos_nz_l1_18 = []
    vs_overseas_l1_06 = []
    vs_overseas_l1_13 = []
    vs_overseas_l1_18 = []
    pos_overseas_l1_06 = []
    pos_overseas_l1_13 = []
    pos_overseas_l1_18 = []
    
    for i in range(0, 16, 5):
        vs_nz_l2_06 = v_nz_born_06[i]
        vs_nz_l1_06.append(vs_nz_l2_06)
        vs_nz_l2_13 = v_nz_born_13[i]
        vs_nz_l1_13.append(vs_nz_l2_13)
        vs_nz_l2_18 = v_nz_born_18[i]
        vs_nz_l1_18.append(vs_nz_l2_18)
        pos_nz_l2_06 = po_nz_born_06[i]
        pos_nz_l1_06.append(pos_nz_l2_06)
        pos_nz_l2_13 = po_nz_born_13[i]
        pos_nz_l1_13.append(pos_nz_l2_13)
        pos_nz_l2_18 = po_nz_born_18[i]
        pos_nz_l1_18.append(pos_nz_l2_18)
        vs_overseas_l2_06 = v_nz_born_06[i]
        vs_overseas_l1_06.append(vs_nz_l2_06)
        vs_overseas_l2_13 = v_nz_born_13[i]
        vs_overseas_l1_13.append(vs_nz_l2_13)
        vs_overseas_l2_18 = v_nz_born_18[i]
        vs_overseas_l1_18.append(vs_nz_l2_18)
        pos_overseas_l2_06 = po_nz_born_06[i]
        pos_overseas_l1_06.append(pos_nz_l2_06)
        pos_overseas_l2_13 = po_nz_born_13[i]
        pos_overseas_l1_13.append(pos_nz_l2_13)
        pos_overseas_l2_18 = po_nz_born_18[i]
        pos_overseas_l1_18.append(pos_nz_l2_18)
    vs_nz_df_06['2006'] = [round(num, 1) for num in pos_nz_l1_06]
    vs_nz_df_13['2013'] = [round(num, 1) for num in pos_nz_l1_13]
    vs_nz_df_18['2018'] = [round(num, 1) for num in pos_nz_l1_18]
    pos_nz_df_06['2006'] = [round(num, 1) for num in pos_nz_l1_06]
    pos_nz_df_13['2013'] = [round(num, 1) for num in pos_nz_l1_13]
    pos_nz_df_18['2018'] = [round(num, 1) for num in pos_nz_l1_18]
    vs_overseas_df_06['2006'] = [round(num, 1) for num in pos_overseas_l1_06]
    vs_overseas_df_13['2013'] = [round(num, 1) for num in pos_overseas_l1_13]
    vs_overseas_df_18['2018'] = [round(num, 1) for num in pos_overseas_l1_18]
    pos_overseas_df_06['2006'] = [round(num, 1) for num in pos_overseas_l1_06]
    pos_overseas_df_13['2013'] = [round(num, 1) for num in pos_overseas_l1_13]
    pos_overseas_df_18['2018'] = [round(num, 1) for num in pos_overseas_l1_18]
    
    vs_nz_df_all = pd.concat([vs_nz_df_06, vs_nz_df_13, vs_nz_df_18], axis=1)
    pos_nz_df_all = pd.concat([pos_nz_df_06, pos_nz_df_13, pos_nz_df_18], axis=1)
    vs_overseas_df_all = pd.concat([vs_overseas_df_06, vs_overseas_df_13, vs_overseas_df_18], axis=1)
    pos_overseas_df_all = pd.concat([pos_overseas_df_06, pos_overseas_df_13, pos_overseas_df_18], axis=1)
    print(vs_nz_df_all)
    print(pos_nz_df_all)
    print(vs_overseas_df_all)
    print(pos_overseas_df_all)
    
    
    
    
    '''plot slr values'''
    plt.plot(slr, v_nz_born_06, label="nz_born 06", color="c")
    plt.annotate('nz_born 2006', (150, v_nz_born_06[15]), textcoords="offset points", xytext=(40,5), fontsize=11, ha='center', color='c')
    plt.plot(slr, v_nz_born_13, label="nz_born 13", color="c")
    plt.annotate('nz_born 2013', (150, v_nz_born_13[15]), textcoords="offset points", xytext=(40,5), fontsize=11, ha='center', color='c')
    plt.plot(slr, v_nz_born_18, label="nz_born 18", color="c")
    plt.annotate('nz_born 2018', (150, v_nz_born_18[15]), textcoords="offset points", xytext=(40,5), fontsize=11, ha='center', color='c')
    plt.plot(slr, v_overseas_born_06, label="overseas_born 06", color="pink")
    plt.annotate('overseas_born 2006', (150, v_overseas_born_06[15]), textcoords="offset points", xytext=overseas_born_ad_offset, fontsize=11, ha='center', color='pink')
    plt.plot(slr, v_overseas_born_13, label="overseas_born 13", color="pink")
    plt.annotate('overseas_born 2013', (150, v_overseas_born_13[15]), textcoords="offset points", xytext=overseas_born_ad_offset, fontsize=11, ha='center', color='pink')
    plt.plot(slr, v_overseas_born_18, label="overseas_born 18", color="pink")
    plt.annotate('overseas_born 2018', (150, v_overseas_born_18[15]), textcoords="offset points", xytext=overseas_born_ad_offset, fontsize=11, ha='center', color='pink')
    plt.xlabel('Sea level rise (cm)')
    plt.ylabel('Number of people exposed')
    plt.title('Number of each location of birth exposed as sea level rise increase, relative to time', y=title_offset)
    ax = plt.subplot(111)
    ax.spines["right"].set_visible(False)
    ax.spines["top"].set_visible(False)
    plt.savefig(rc + '_value_location of birth.png')
    plt.show()
    
    ''' plot slr percentages '''
    plt.plot(slr, p_nz_born_06, label="nz_born 06", color="c")
    plt.annotate('nz_born 2006', (150, p_nz_born_06[15]), textcoords="offset points", xytext=(40,5), fontsize=11, ha='center', color='c')
    plt.plot(slr, p_nz_born_13, label="nz_born 13", color="c")
    plt.annotate('nz_born 2013', (150, p_nz_born_13[15]), textcoords="offset points", xytext=(40,5), fontsize=11, ha='center', color='c')
    plt.plot(slr, p_nz_born_18, label="nz_born 18", color="c")
    plt.annotate('nz_born 2018', (150, p_nz_born_18[15]), textcoords="offset points", xytext=(40,5), fontsize=11, ha='center', color='c')
    plt.plot(slr, p_overseas_born_06, label="overseas_born 06", color="pink")
    plt.annotate('overseas_born 2006', (150, p_overseas_born_06[15]), textcoords="offset points", xytext=overseas_born_ad_offset, fontsize=11, ha='center', color='pink')
    plt.plot(slr, p_overseas_born_13, label="overseas_born 13", color="pink")
    plt.annotate('overseas_born 2013', (150, p_overseas_born_13[15]), textcoords="offset points", xytext=overseas_born_ad_offset, fontsize=11, ha='center', color='pink')
    plt.plot(slr, p_overseas_born_18, label="overseas_born 18", color="pink")
    plt.annotate('overseas_born 2018', (150, p_overseas_born_18[15]), textcoords="offset points", xytext=overseas_born_ad_offset, fontsize=11, ha='center', color='pink')
    plt.xlabel('Sea level rise (cm)')
    plt.ylabel('Percentage of people exposed (%)')
    plt.title('Percentage of each location of birth exposed as sea level rise increase, relative to time', y=title_offset)
    ax = plt.subplot(111)
    ax.spines["right"].set_visible(False)
    ax.spines["top"].set_visible(False)
    plt.savefig(rc + '_p_location of birth.png')
    plt.show()
    
    '''plot slr percentage change '''
    plt.plot(slr, pc_nz_born_06, label="nz_born 06", color="c")
    plt.annotate('nz_born 2006', (150, pc_nz_born_06[15]), textcoords="offset points", xytext=(40,5), fontsize=11, ha='center', color='c')
    plt.plot(slr, pc_nz_born_13, label="nz_born 13", color="c")
    plt.annotate('nz_born 2013', (150, pc_nz_born_13[15]), textcoords="offset points", xytext=(40,5), fontsize=11, ha='center', color='c')
    plt.plot(slr, pc_nz_born_18, label="nz_born 18", color="c")
    plt.annotate('nz_born 2018', (150, pc_nz_born_18[15]), textcoords="offset points", xytext=(40,5), fontsize=11, ha='center', color='c')
    plt.plot(slr, pc_overseas_born_06, label="overseas_born 06", color="pink")
    plt.annotate('overseas_born 2006', (150, pc_overseas_born_06[15]), textcoords="offset points", xytext=overseas_born_ad_offset, fontsize=11, ha='center', color='pink')
    plt.plot(slr, pc_overseas_born_13, label="overseas_born 13", color="pink")
    plt.annotate('overseas_born 2013', (150, pc_overseas_born_13[15]), textcoords="offset points", xytext=overseas_born_ad_offset, fontsize=11, ha='center', color='pink')
    plt.plot(slr, pc_overseas_born_18, label="overseas_born 18", color="pink")
    plt.annotate('overseas_born 2018', (150, pc_overseas_born_18[15]), textcoords="offset points", xytext=overseas_born_ad_offset, fontsize=11, ha='center', color='pink')
    plt.xlabel('Sea level rise (cm)')
    plt.ylabel('Percentage chnage of people exposed (%)')
    plt.title('Percentage change of each location of birth exposed as sea level rise increase, relative to time', y=title_offset)
    ax = plt.subplot(111)
    ax.spines["right"].set_visible(False)
    ax.spines["top"].set_visible(False)
    plt.savefig(rc + '_pc_location of birth.jpg')
    plt.show()
    
    
    '''plot slr percentage overall '''
    plt.plot(slr, po_nz_born_06, label="nz_born 06", color="c")
    plt.annotate('nz_born 2006', (150, po_nz_born_06[15]), textcoords="offset points", xytext=(40,5), fontsize=11, ha='center', color='c')
    plt.plot(slr, po_nz_born_13, label="nz_born 13", color="c")
    plt.annotate('nz_born 2013', (150, po_nz_born_13[15]), textcoords="offset points", xytext=(40,5), fontsize=11, ha='center', color='c')
    plt.plot(slr, po_nz_born_18, label="nz_born 18", color="c")
    plt.annotate('nz_born 2018', (150, po_nz_born_18[15]), textcoords="offset points", xytext=(40,5), fontsize=11, ha='center', color='c')
    plt.plot(slr, po_overseas_born_06, label="overseas_born 06", color="pink")
    plt.annotate('overseas_born 2006', (150, po_overseas_born_06[15]), textcoords="offset points", xytext=overseas_born_ad_offset, fontsize=11, ha='center', color='pink')
    plt.plot(slr, po_overseas_born_13, label="overseas_born 13", color="pink")
    plt.annotate('overseas_born 2013', (150, po_overseas_born_13[15]), textcoords="offset points", xytext=overseas_born_ad_offset, fontsize=11, ha='center', color='pink')
    plt.plot(slr, po_overseas_born_18, label="overseas_born 18", color="pink")
    plt.annotate('overseas_born 2018', (150, po_overseas_born_18[15]), textcoords="offset points", xytext=overseas_born_ad_offset, fontsize=11, ha='center', color='pink')
    plt.xlabel('Sea level rise (cm)')
    plt.ylabel('Percentage of people exposed (%)')
    plt.title('Percentage of each location of birth exposed as sea level rise increase, relative to time', y=title_offset)
    ax = plt.subplot(111)
    ax.spines["right"].set_visible(False)
    ax.spines["top"].set_visible(False)
    plt.savefig(rc + '_po_location of birth.jpg')
    plt.show()
    
    
    '''values slr increase percentage of overall population'''

# %%
'''maori descent'''

#slr progression - maori descent 



rc_names  = ['southland', 'otago'] 
rc_names_abrv = ['Southland', 'Otago'] 


for i in range(0, 2, 1):
    rc = rc_names[i]
    print(rc)
    '''collate relevent data'''
    v_maori_decent_06 = [regional_dict[rc]['slr_{}'.format(i)]['C06_Maori_'] for i in range(0,160,10)]
    v_maori_decent_13 = [regional_dict[rc]['slr_{}'.format(i)]['C13_Maori_'] for i in range(0,160,10)]
    v_maori_decent_18 = [regional_dict[rc]['slr_{}'.format(i)]['C18_Maori_'] for i in range(0,160,10)]
    v_no_maori_decent_06 = [regional_dict[rc]['slr_{}'.format(i)]['C06_Maor_1'] for i in range(0,160,10)]
    v_no_maori_decent_13 = [regional_dict[rc]['slr_{}'.format(i)]['C13_Maor_1'] for i in range(0,160,10)]
    v_no_maori_decent_18 = [regional_dict[rc]['slr_{}'.format(i)]['C18_Maor_1'] for i in range(0,160,10)]
    total_06 = [sum(x) for x in zip(v_maori_decent_06, v_no_maori_decent_06)]
    total_13 = [sum(x) for x in zip(v_maori_decent_13, v_no_maori_decent_13)]
    total_18 = [sum(x) for x in zip(v_maori_decent_18, v_no_maori_decent_18)]
    p_maori_decent_06 = [((x/y)*100) for x, y in zip(v_maori_decent_06, total_06)]
    p_maori_decent_13 = [((x/y)*100) for x, y in zip(v_maori_decent_13, total_13)]
    p_maori_decent_18 = [((x/y)*100) for x, y in zip(v_maori_decent_18, total_18)]
    p_no_maori_decent_06 = [((x/y)*100) for x, y in zip(v_no_maori_decent_06, total_06)]
    p_no_maori_decent_13 = [((x/y)*100) for x, y in zip(v_no_maori_decent_13, total_13)]
    p_no_maori_decent_18 = [((x/y)*100) for x, y in zip(v_no_maori_decent_18, total_18)]
    r_maori_decent_06 = [regional_noslr_dict[rc]['C06_Maori_'] for i in range(0, 160, 10)]
    r_maori_decent_13 = [regional_noslr_dict[rc]['C13_Maori_'] for i in range(0, 160, 10)]
    r_maori_decent_18 = [regional_noslr_dict[rc]['C18_Maori_'] for i in range(0, 160, 10)]
    r_no_maori_decent_06 = [regional_noslr_dict[rc]['C06_Maor_1'] for i in range(0, 160, 10)]
    r_no_maori_decent_13 = [regional_noslr_dict[rc]['C13_Maor_1'] for i in range(0, 160, 10)]
    r_no_maori_decent_18 = [regional_noslr_dict[rc]['C18_Maor_1'] for i in range(0, 160, 10)]
    pc_maori_decent_06 = [z-(x/((x+y)/100)) for x, y, z in zip(r_maori_decent_06, r_no_maori_decent_06, p_maori_decent_06)]
    pc_maori_decent_13 = [z-(x/((x+y)/100)) for x, y, z in zip(r_maori_decent_13, r_no_maori_decent_13, p_maori_decent_13)]
    pc_maori_decent_18 = [z-(x/((x+y)/100)) for x, y, z in zip(r_maori_decent_18, r_no_maori_decent_18, p_maori_decent_18)]
    pc_no_maori_decent_06 = [z-(x/((x+y)/100)) for x, y, z in zip(r_no_maori_decent_06, r_no_maori_decent_06, p_no_maori_decent_06)]
    pc_no_maori_decent_13 = [z-(x/((x+y)/100)) for x, y, z in zip(r_no_maori_decent_13, r_no_maori_decent_13, p_no_maori_decent_13)]
    pc_no_maori_decent_18 = [z-(x/((x+y)/100)) for x, y, z in zip(r_no_maori_decent_18, r_no_maori_decent_18, p_no_maori_decent_18)]
    po_maori_decent_06 = [x/(y/100) for x, y in zip(v_maori_decent_06, r_maori_decent_06)]
    po_maori_decent_13 = [x/(y/100) for x, y in zip(v_maori_decent_13, r_maori_decent_13)]
    po_maori_decent_18 = [x/(y/100) for x, y in zip(v_maori_decent_18, r_maori_decent_18)]
    po_no_maori_decent_06 = [x/(y/100) for x, y in zip(v_no_maori_decent_06, r_no_maori_decent_06)]
    po_no_maori_decent_13 = [x/(y/100) for x, y in zip(v_no_maori_decent_13, r_no_maori_decent_13)]
    po_no_maori_decent_18 = [x/(y/100) for x, y in zip(v_no_maori_decent_18, r_no_maori_decent_18)]

    '''make all this plotting useful and orderly'''   
    title_offset = 1.03
    no_maori_decent_ad_offset = (115, 0)
    
    '''creating values'''
    slr_short = [0, 50, 100, 150]
    vs_maori_decent_df_06 = pd.DataFrame({'slr' : slr_short})
    vs_maori_decent_df_06.columns.name = rc
    vs_maori_decent_df_13 = pd.DataFrame({'slr' : slr_short})
    vs_maori_decent_df_13.columns.name = rc
    vs_maori_decent_df_18 = pd.DataFrame({'slr' : slr_short})
    vs_maori_decent_df_18.columns.name = rc
    vs_no_maori_decent_df_06 = pd.DataFrame({'slr' : slr_short})
    vs_no_maori_decent_df_06.columns.name = rc
    vs_no_maori_decent_df_13 = pd.DataFrame({'slr' : slr_short})
    vs_no_maori_decent_df_13.columns.name = rc
    vs_no_maori_decent_df_18 = pd.DataFrame({'slr' : slr_short})
    vs_no_maori_decent_df_18.columns.name = rc
    pos_maori_decent_df_06 = pd.DataFrame({'slr' : slr_short})
    pos_maori_decent_df_06.columns.name = rc
    pos_maori_decent_df_13 = pd.DataFrame({'slr' : slr_short})
    pos_maori_decent_df_13.columns.name = rc
    pos_maori_decent_df_18 = pd.DataFrame({'slr' : slr_short})
    pos_maori_decent_df_18.columns.name = rc
    pos_no_maori_decent_df_06 = pd.DataFrame({'slr' : slr_short})
    pos_no_maori_decent_df_06.columns.name = rc
    pos_no_maori_decent_df_13 = pd.DataFrame({'slr' : slr_short})
    pos_no_maori_decent_df_13.columns.name = rc
    pos_no_maori_decent_df_18 = pd.DataFrame({'slr' : slr_short})
    pos_no_maori_decent_df_18.columns.name = rc
    
    vs_maori_decent_l1_06 = []
    vs_maori_decent_l1_13 = []
    vs_maori_decent_l1_18 = []
    pos_maori_decent_l1_06 = []
    pos_maori_decent_l1_13 = []
    pos_maori_decent_l1_18 = []
    vs_no_maori_decent_l1_06 = []
    vs_no_maori_decent_l1_13 = []
    vs_no_maori_decent_l1_18 = []
    pos_no_maori_decent_l1_06 = []
    pos_no_maori_decent_l1_13 = []
    pos_no_maori_decent_l1_18 = []
    
    for i in range(0, 16, 5):
        vs_maori_decent_l2_06 = v_maori_decent_06[i]
        vs_maori_decent_l1_06.append(vs_maori_decent_l2_06)
        vs_maori_decent_l2_13 = v_maori_decent_13[i]
        vs_maori_decent_l1_13.append(vs_maori_decent_l2_13)
        vs_maori_decent_l2_18 = v_maori_decent_18[i]
        vs_maori_decent_l1_18.append(vs_maori_decent_l2_18)
        pos_maori_decent_l2_06 = po_maori_decent_06[i]
        pos_maori_decent_l1_06.append(pos_maori_decent_l2_06)
        pos_maori_decent_l2_13 = po_maori_decent_13[i]
        pos_maori_decent_l1_13.append(pos_maori_decent_l2_13)
        pos_maori_decent_l2_18 = po_maori_decent_18[i]
        pos_maori_decent_l1_18.append(pos_maori_decent_l2_18)
        vs_no_maori_decent_l2_06 = v_maori_decent_06[i]
        vs_no_maori_decent_l1_06.append(vs_maori_decent_l2_06)
        vs_no_maori_decent_l2_13 = v_maori_decent_13[i]
        vs_no_maori_decent_l1_13.append(vs_maori_decent_l2_13)
        vs_no_maori_decent_l2_18 = v_maori_decent_18[i]
        vs_no_maori_decent_l1_18.append(vs_maori_decent_l2_18)
        pos_no_maori_decent_l2_06 = po_maori_decent_06[i]
        pos_no_maori_decent_l1_06.append(pos_maori_decent_l2_06)
        pos_no_maori_decent_l2_13 = po_maori_decent_13[i]
        pos_no_maori_decent_l1_13.append(pos_maori_decent_l2_13)
        pos_no_maori_decent_l2_18 = po_maori_decent_18[i]
        pos_no_maori_decent_l1_18.append(pos_maori_decent_l2_18)
    vs_maori_decent_df_06['2006'] = [round(num, 1) for num in pos_maori_decent_l1_06]
    vs_maori_decent_df_13['2013'] = [round(num, 1) for num in pos_maori_decent_l1_13]
    vs_maori_decent_df_18['2018'] = [round(num, 1) for num in pos_maori_decent_l1_18]
    pos_maori_decent_df_06['2006'] = [round(num, 1) for num in pos_maori_decent_l1_06]
    pos_maori_decent_df_13['2013'] = [round(num, 1) for num in pos_maori_decent_l1_13]
    pos_maori_decent_df_18['2018'] = [round(num, 1) for num in pos_maori_decent_l1_18]
    vs_no_maori_decent_df_06['2006'] = [round(num, 1) for num in pos_no_maori_decent_l1_06]
    vs_no_maori_decent_df_13['2013'] = [round(num, 1) for num in pos_no_maori_decent_l1_13]
    vs_no_maori_decent_df_18['2018'] = [round(num, 1) for num in pos_no_maori_decent_l1_18]
    pos_no_maori_decent_df_06['2006'] = [round(num, 1) for num in pos_no_maori_decent_l1_06]
    pos_no_maori_decent_df_13['2013'] = [round(num, 1) for num in pos_no_maori_decent_l1_13]
    pos_no_maori_decent_df_18['2018'] = [round(num, 1) for num in pos_no_maori_decent_l1_18]
    
    vs_maori_decent_df_all = pd.concat([vs_maori_decent_df_06, vs_maori_decent_df_13, vs_maori_decent_df_18], axis=1)
    pos_maori_decent_df_all = pd.concat([pos_maori_decent_df_06, pos_maori_decent_df_13, pos_maori_decent_df_18], axis=1)
    vs_no_maori_decent_df_all = pd.concat([vs_no_maori_decent_df_06, vs_no_maori_decent_df_13, vs_no_maori_decent_df_18], axis=1)
    pos_no_maori_decent_df_all = pd.concat([pos_no_maori_decent_df_06, pos_no_maori_decent_df_13, pos_no_maori_decent_df_18], axis=1)
    print(vs_maori_decent_df_all)
    print(pos_maori_decent_df_all)
    print(vs_no_maori_decent_df_all)
    print(pos_no_maori_decent_df_all)
    
    
    
    
    '''plot slr values'''
    plt.plot(slr, v_maori_decent_06, label="maori_decent 06", color="c")
    plt.annotate('maori_decent 2006', (150, v_maori_decent_06[15]), textcoords="offset points", xytext=(40,5), fontsize=11, ha='center', color='c')
    plt.plot(slr, v_maori_decent_13, label="maori_decent 13", color="c")
    plt.annotate('maori_decent 2013', (150, v_maori_decent_13[15]), textcoords="offset points", xytext=(40,5), fontsize=11, ha='center', color='c')
    plt.plot(slr, v_maori_decent_18, label="maori_decent 18", color="c")
    plt.annotate('maori_decent 2018', (150, v_maori_decent_18[15]), textcoords="offset points", xytext=(40,5), fontsize=11, ha='center', color='c')
    plt.plot(slr, v_no_maori_decent_06, label="no_maori_decent 06", color="pink")
    plt.annotate('no_maori_decent 2006', (150, v_no_maori_decent_06[15]), textcoords="offset points", xytext=no_maori_decent_ad_offset, fontsize=11, ha='center', color='pink')
    plt.plot(slr, v_no_maori_decent_13, label="no_maori_decent 13", color="pink")
    plt.annotate('no_maori_decent 2013', (150, v_no_maori_decent_13[15]), textcoords="offset points", xytext=no_maori_decent_ad_offset, fontsize=11, ha='center', color='pink')
    plt.plot(slr, v_no_maori_decent_18, label="no_maori_decent 18", color="pink")
    plt.annotate('no_maori_decent 2018', (150, v_no_maori_decent_18[15]), textcoords="offset points", xytext=no_maori_decent_ad_offset, fontsize=11, ha='center', color='pink')
    plt.xlabel('Sea level rise (cm)')
    plt.ylabel('Number of people exposed')
    plt.title('Number of each Maori or No-Maori descent exposed as sea level rise increase, relative to time', y=title_offset)
    ax = plt.subplot(111)
    ax.spines["right"].set_visible(False)
    ax.spines["top"].set_visible(False)
    plt.savefig(rc + '_value_Maori or No-Maori descent.png')
    plt.show()
    
    ''' plot slr percentages '''
    plt.plot(slr, p_maori_decent_06, label="maori_decent 06", color="c")
    plt.annotate('maori_decent 2006', (150, p_maori_decent_06[15]), textcoords="offset points", xytext=(40,5), fontsize=11, ha='center', color='c')
    plt.plot(slr, p_maori_decent_13, label="maori_decent 13", color="c")
    plt.annotate('maori_decent 2013', (150, p_maori_decent_13[15]), textcoords="offset points", xytext=(40,5), fontsize=11, ha='center', color='c')
    plt.plot(slr, p_maori_decent_18, label="maori_decent 18", color="c")
    plt.annotate('maori_decent 2018', (150, p_maori_decent_18[15]), textcoords="offset points", xytext=(40,5), fontsize=11, ha='center', color='c')
    plt.plot(slr, p_no_maori_decent_06, label="no_maori_decent 06", color="pink")
    plt.annotate('no_maori_decent 2006', (150, p_no_maori_decent_06[15]), textcoords="offset points", xytext=no_maori_decent_ad_offset, fontsize=11, ha='center', color='pink')
    plt.plot(slr, p_no_maori_decent_13, label="no_maori_decent 13", color="pink")
    plt.annotate('no_maori_decent 2013', (150, p_no_maori_decent_13[15]), textcoords="offset points", xytext=no_maori_decent_ad_offset, fontsize=11, ha='center', color='pink')
    plt.plot(slr, p_no_maori_decent_18, label="no_maori_decent 18", color="pink")
    plt.annotate('no_maori_decent 2018', (150, p_no_maori_decent_18[15]), textcoords="offset points", xytext=no_maori_decent_ad_offset, fontsize=11, ha='center', color='pink')
    plt.xlabel('Sea level rise (cm)')
    plt.ylabel('Percentage of people exposed (%)')
    plt.title('Percentage of each Maori or No-Maori descent exposed as sea level rise increase, relative to time', y=title_offset)
    ax = plt.subplot(111)
    ax.spines["right"].set_visible(False)
    ax.spines["top"].set_visible(False)
    plt.savefig(rc + '_p_Maori or No-Maori descent.png')
    plt.show()
    
    '''plot slr percentage change '''
    plt.plot(slr, pc_maori_decent_06, label="maori_decent 06", color="c")
    plt.annotate('maori_decent 2006', (150, pc_maori_decent_06[15]), textcoords="offset points", xytext=(40,5), fontsize=11, ha='center', color='c')
    plt.plot(slr, pc_maori_decent_13, label="maori_decent 13", color="c")
    plt.annotate('maori_decent 2013', (150, pc_maori_decent_13[15]), textcoords="offset points", xytext=(40,5), fontsize=11, ha='center', color='c')
    plt.plot(slr, pc_maori_decent_18, label="maori_decent 18", color="c")
    plt.annotate('maori_decent 2018', (150, pc_maori_decent_18[15]), textcoords="offset points", xytext=(40,5), fontsize=11, ha='center', color='c')
    plt.plot(slr, pc_no_maori_decent_06, label="no_maori_decent 06", color="pink")
    plt.annotate('no_maori_decent 2006', (150, pc_no_maori_decent_06[15]), textcoords="offset points", xytext=no_maori_decent_ad_offset, fontsize=11, ha='center', color='pink')
    plt.plot(slr, pc_no_maori_decent_13, label="no_maori_decent 13", color="pink")
    plt.annotate('no_maori_decent 2013', (150, pc_no_maori_decent_13[15]), textcoords="offset points", xytext=no_maori_decent_ad_offset, fontsize=11, ha='center', color='pink')
    plt.plot(slr, pc_no_maori_decent_18, label="no_maori_decent 18", color="pink")
    plt.annotate('no_maori_decent 2018', (150, pc_no_maori_decent_18[15]), textcoords="offset points", xytext=no_maori_decent_ad_offset, fontsize=11, ha='center', color='pink')
    plt.xlabel('Sea level rise (cm)')
    plt.ylabel('Percentage chnage of people exposed (%)')
    plt.title('Percentage change of each Maori or No-Maori descent exposed as sea level rise increase, relative to time', y=title_offset)
    ax = plt.subplot(111)
    ax.spines["right"].set_visible(False)
    ax.spines["top"].set_visible(False)
    plt.savefig(rc + '_pc_Maori or No-Maori descent.jpg')
    plt.show()
    
    
    '''plot slr percentage overall '''
    plt.plot(slr, po_maori_decent_06, label="maori_decent 06", color="c")
    plt.annotate('maori_decent 2006', (150, po_maori_decent_06[15]), textcoords="offset points", xytext=(40,5), fontsize=11, ha='center', color='c')
    plt.plot(slr, po_maori_decent_13, label="maori_decent 13", color="c")
    plt.annotate('maori_decent 2013', (150, po_maori_decent_13[15]), textcoords="offset points", xytext=(40,5), fontsize=11, ha='center', color='c')
    plt.plot(slr, po_maori_decent_18, label="maori_decent 18", color="c")
    plt.annotate('maori_decent 2018', (150, po_maori_decent_18[15]), textcoords="offset points", xytext=(40,5), fontsize=11, ha='center', color='c')
    plt.plot(slr, po_no_maori_decent_06, label="no_maori_decent 06", color="pink")
    plt.annotate('no_maori_decent 2006', (150, po_no_maori_decent_06[15]), textcoords="offset points", xytext=no_maori_decent_ad_offset, fontsize=11, ha='center', color='pink')
    plt.plot(slr, po_no_maori_decent_13, label="no_maori_decent 13", color="pink")
    plt.annotate('no_maori_decent 2013', (150, po_no_maori_decent_13[15]), textcoords="offset points", xytext=no_maori_decent_ad_offset, fontsize=11, ha='center', color='pink')
    plt.plot(slr, po_no_maori_decent_18, label="no_maori_decent 18", color="pink")
    plt.annotate('no_maori_decent 2018', (150, po_no_maori_decent_18[15]), textcoords="offset points", xytext=no_maori_decent_ad_offset, fontsize=11, ha='center', color='pink')
    plt.xlabel('Sea level rise (cm)')
    plt.ylabel('Percentage of people exposed (%)')
    plt.title('Percentage of each Maori or No-Maori descent exposed as sea level rise increase, relative to time', y=title_offset)
    ax = plt.subplot(111)
    ax.spines["right"].set_visible(False)
    ax.spines["top"].set_visible(False)
    plt.savefig(rc + '_po_Maori or No-Maori descent.jpg')
    plt.show()
    
    
    '''values slr increase percentage of overall population'''

# %%
'''collate relevent data'''
#time progession - gender 

for rc in rc_names:
    print(rc)
    df_years = pd.DataFrame({'years' : years})
    '''collate relevent data'''
    v_female_06 = [regional_dict[rc]['slr_{}'.format(i)]['C06_Sex_Fe'] for i in range(0,160,10)]
    v_female_13 = [regional_dict[rc]['slr_{}'.format(i)]['C13_Sex_Fe'] for i in range(0,160,10)]
    v_female_18 = [regional_dict[rc]['slr_{}'.format(i)]['C18_Sex_Fe'] for i in range(0,160,10)]
    v_male_06 = [regional_dict[rc]['slr_{}'.format(i)]['C06_Sex_Ma'] for i in range(0,160,10)]
    v_male_13 = [regional_dict[rc]['slr_{}'.format(i)]['C13_Sex_Ma'] for i in range(0,160,10)]
    v_male_18 = [regional_dict[rc]['slr_{}'.format(i)]['C18_Sex_Ma'] for i in range(0,160,10)]
    total_06 = [sum(x) for x in zip(v_female_06, v_male_06)]
    total_13 = [sum(x) for x in zip(v_female_13, v_male_13)]
    total_18 = [sum(x) for x in zip(v_female_18, v_male_18)]
    p_female_06 = [((x/y)*100) for x, y in zip(v_female_06, total_06)]
    p_female_13 = [((x/y)*100) for x, y in zip(v_female_13, total_13)]
    p_female_18 = [((x/y)*100) for x, y in zip(v_female_18, total_18)]
    p_male_06 = [((x/y)*100) for x, y in zip(v_male_06, total_06)]
    p_male_13 = [((x/y)*100) for x, y in zip(v_male_13, total_13)]
    p_male_18 = [((x/y)*100) for x, y in zip(v_male_18, total_18)]
    r_female_06 = [regional_noslr_dict[rc]['C06_Sex_Fe'] for i in range(0, 160, 10)]
    r_female_13 = [regional_noslr_dict[rc]['C13_Sex_Fe'] for i in range(0, 160, 10)]
    r_female_18 = [regional_noslr_dict[rc]['C18_Sex_Fe'] for i in range(0, 160, 10)]
    r_male_06 = [regional_noslr_dict[rc]['C06_Sex_Ma'] for i in range(0, 160, 10)]
    r_male_13 = [regional_noslr_dict[rc]['C13_Sex_Ma'] for i in range(0, 160, 10)]
    r_male_18 = [regional_noslr_dict[rc]['C18_Sex_Ma'] for i in range(0, 160, 10)]
    pc_female_06 = [z-(x/((x+y)/100)) for x, y, z in zip(r_female_06, r_male_06, p_female_06)]
    pc_female_13 = [z-(x/((x+y)/100)) for x, y, z in zip(r_female_13, r_male_13, p_female_13)]
    pc_female_18 = [z-(x/((x+y)/100)) for x, y, z in zip(r_female_18, r_male_18, p_female_18)]
    pc_male_06 = [z-(x/((x+y)/100)) for x, y, z in zip(r_male_06, r_male_06, p_male_06)]
    pc_male_13 = [z-(x/((x+y)/100)) for x, y, z in zip(r_male_13, r_male_13, p_male_13)]
    pc_male_18 = [z-(x/((x+y)/100)) for x, y, z in zip(r_male_18, r_male_18, p_male_18)]
    po_female_06 = [x/(y/100) for x, y in zip(v_female_06, r_female_06)]
    po_female_13 = [x/(y/100) for x, y in zip(v_female_13, r_female_13)]
    po_female_18 = [x/(y/100) for x, y in zip(v_female_18, r_female_18)]
    po_male_06 = [x/(y/100) for x, y in zip(v_male_06, r_male_06)]
    po_male_13 = [x/(y/100) for x, y in zip(v_male_13, r_male_13)]
    po_male_18 = [x/(y/100) for x, y in zip(v_male_18, r_male_18)]
    
    '''female'''
    v_fem_dict_time = {}
    p_fem_dict_time = {}
    pc_fem_dict_time = {}
    po_fem_dict_time = {}
    
    if rc == 'otago':
        rc = 'otago   '
    
    v_fem_df = pd.DataFrame({'years' : years})
    v_fem_df.columns.name = rc
    p_fem_df = pd.DataFrame({'years' : years})
    p_fem_df.columns.name = rc
    pc_fem_df = pd.DataFrame({'years' : years})
    pc_fem_df.columns.name = rc
    po_fem_df = pd.DataFrame({'years' : years})
    po_fem_df.columns.name = rc
    
    for i in range(0, 16, 1):
        v_fem_time = []
        v_fem_time.append(v_female_06[i])
        v_fem_time.append(v_female_13[i])
        v_fem_time.append(v_female_18[i])
        v_fem_dict_time.update({'slr_{}0'.format(i) : v_fem_time})
        p_fem_time = []
        p_fem_time.append(p_female_06[i])
        p_fem_time.append(p_female_13[i])
        p_fem_time.append(p_female_18[i])
        p_fem_dict_time.update({'slr_{}0'.format(i) : p_fem_time})
        pc_fem_time = []
        pc_fem_time.append(pc_female_06[i])
        pc_fem_time.append(pc_female_13[i])
        pc_fem_time.append(pc_female_18[i])
        pc_fem_dict_time.update({'slr_{}0'.format(i) : pc_fem_time})
        po_fem_time = []
        po_fem_time.append(po_female_06[i])
        po_fem_time.append(po_female_13[i])
        po_fem_time.append(po_female_18[i])
        po_fem_dict_time.update({'slr_{}0'.format(i) : po_fem_time})
        if i == 0 or i == 5 or i == 10:
            v_fem_df['slr_{}0'.format(i)] = v_fem_time
            po_fem_df['slr_{}0'.format(i)] = [round(num, 1) for num in po_fem_time]
        
        
    '''male'''
    v_mal_dict_time = {}
    p_mal_dict_time = {}
    pc_mal_dict_time = {}
    po_mal_dict_time = {}
    
    if rc == 'otago':
        rc = 'otago   '
    
    v_mal_df = pd.DataFrame({'years' : years})
    v_mal_df.columns.name = rc
    po_mal_df = pd.DataFrame({'years' : years})
    po_mal_df.columns.name = rc
    
    for i in range(0, 16, 1):
        v_mal_time = []
        v_mal_time.append(v_male_06[i])
        v_mal_time.append(v_male_13[i])
        v_mal_time.append(v_male_18[i])
        v_mal_dict_time.update({'slr_{}0'.format(i) : v_mal_time})
        p_mal_time = []
        p_mal_time.append(p_male_06[i])
        p_mal_time.append(p_male_13[i])
        p_mal_time.append(p_male_18[i])
        p_mal_dict_time.update({'slr_{}0'.format(i) : p_mal_time})
        pc_mal_time = []
        pc_mal_time.append(pc_male_06[i])
        pc_mal_time.append(pc_male_13[i])
        pc_mal_time.append(pc_male_18[i])
        pc_mal_dict_time.update({'slr_{}0'.format(i) : pc_mal_time})
        po_mal_time = []
        po_mal_time.append(po_male_06[i])
        po_mal_time.append(po_male_13[i])
        po_mal_time.append(po_male_18[i])
        po_mal_dict_time.update({'slr_{}0'.format(i) : po_mal_time})
        if i == 0 or i == 5 or i == 10:
            v_mal_df['slr_{}0'.format(i)] = v_mal_time
            po_mal_df['slr_{}0'.format(i)] = [round(num, 1) for num in po_mal_time]
    
    
    '''make all this data useful and orderly'''
    gender_dict_time = {'female_value' : v_fem_dict_time, 'female_percentage' : p_fem_dict_time, 'female_pc' : pc_fem_dict_time, 'female_po' : po_fem_dict_time, 'male_value' : v_mal_dict_time, 'male_percentage' : p_mal_dict_time, 'male_pc' : pc_mal_dict_time, 'male_po' : po_mal_dict_time}
    years = [2006, 2013, 2018]
    title_offset = 1.03

    
    ''' plot against time numbers '''
    for i in range(0, 11, 5):
        x = 'slr_'+ str(i) + '0'
        y = "female " + str(i) + "0cm"
        plt.plot(years, gender_dict_time['female_value'][x], label=y, color="c")
        plt.annotate(y, (2018, gender_dict_time['female_value'][x][2]), textcoords="offset points", xytext=(40,5), fontsize=11, ha='center', color='c')
    for i in range(0, 11, 5):
        x = 'slr_'+ str(i) + '0'
        y = "male " + str(i) + "0cm"
        plt.plot(years, gender_dict_time['male_value'][x], label=y, color="pink")
        plt.annotate(y, (2018, gender_dict_time['male_value'][x][2]), textcoords="offset points", xytext=(115,0), fontsize=11, ha='center', color='pink')
        plt.xlabel('Year')
        plt.ylabel('Number of people exposed')
        plt.title('Number of each gender exposed to sea level rise against time', y=title_offset)
        ax = plt.subplot(111)
        ax.spines["right"].set_visible(False)
        ax.spines["top"].set_visible(False)
    plt.figure(figsize=(10.4, 8))
    plt.show()
    
    
    ''' plot against time  percentages '''
    for i in range(0, 11, 5):
        x = 'slr_'+ str(i) + '0'
        y = "female " + str(i) + "0cm"
        plt.plot(years, gender_dict_time['female_percentage'][x], label=y, color="c")
        plt.annotate(y, (2018, gender_dict_time['female_percentage'][x][2]), textcoords="offset points", xytext=(40,0), fontsize=11, ha='center', color='c')
    for i in range(0, 11, 5):
        x = 'slr_'+ str(i) + '0'
        y = "male " + str(i) + "0cm"
        plt.plot(years, gender_dict_time['male_percentage'][x], label=y, color="pink")
        plt.annotate(y, (2018, gender_dict_time['male_percentage'][x][2]), textcoords="offset points", xytext=(40,0), fontsize=11, ha='center', color='pink')
        plt.xlabel('Year')
        plt.ylabel('Percentage of people exposed')
        plt.title('Percentage of each gender exposed to sea level rise against time', y=title_offset)
        ax = plt.subplot(111)
        ax.spines["right"].set_visible(False)
        ax.spines["top"].set_visible(False)
    plt.show()
    
    
    ''' plot against time percentage change '''
    for i in range(0, 11, 5):
        x = 'slr_'+ str(i) + '0'
        y = "female " + str(i) + "0cm"
        plt.plot(years, gender_dict_time['female_pc'][x], label=y, color="c")
        plt.annotate(y, (2018, gender_dict_time['female_pc'][x][2]), textcoords="offset points", xytext=(40,0), fontsize=11, ha='center', color='c')
    for i in range(0, 11, 5):
        x = 'slr_'+ str(i) + '0'
        y = "male " + str(i) + "0cm"
        plt.plot(years, gender_dict_time['male_pc'][x], label=y, color="pink")
        plt.annotate(y, (2018, gender_dict_time['male_pc'][x][2]), textcoords="offset points", xytext=(40,0), fontsize=11, ha='center', color='pink')
        plt.xlabel('Year')
        plt.ylabel('Percentage change of people exposed')
        plt.title('Percentage change of each gender exposed to sea level rise against time', y=title_offset)
        ax = plt.subplot(111)
        ax.spines["right"].set_visible(False)
        ax.spines["top"].set_visible(False)
    plt.show()
    
    
    '''plot slr increase percentage of overall population'''
    for i in range(0, 11, 5):
        x = 'slr_'+ str(i) + '0'
        y = "female " + str(i) + "0cm"
        plt.plot(years, gender_dict_time['female_po'][x], label=y, color="c")
        plt.annotate(y, (2018, gender_dict_time['female_po'][x][2]), textcoords="offset points", xytext=(40,5), fontsize=11, ha='center', color='c')
    for i in range(0, 11, 5):
        x = 'slr_'+ str(i) + '0'
        y = "male " + str(i) + "0cm"
        plt.plot(years, gender_dict_time['male_po'][x], label=y, color="pink")
        plt.annotate(y, (2018, gender_dict_time['male_po'][x][2]), textcoords="offset points", xytext=(115,0), fontsize=11, ha='center', color='pink')
        plt.xlabel('Year')
        plt.ylabel('Percentage of overall population exposed')
        plt.title('Percentage of overall population of each gender exposed to sea level rise against time', y=title_offset)
        ax = plt.subplot(111)
        ax.spines["right"].set_visible(False)
        ax.spines["top"].set_visible(False)
    plt.show()
    

    '''values and percentage of overall in table'''
    fem_all_df = pd.concat([v_fem_df, po_fem_df ], axis=1)
    mal_all_df = pd.concat([v_mal_df, po_mal_df ], axis=1)
    print(fem_all_df)
    print(fem_all_df)

# %%
#time progression - nz born or overseas 

for rc in rc_names:
    print(rc)
    df_years = pd.DataFrame({'years' : years})
    '''collate relevent data'''
    v_nz_born_06 = [regional_dict[rc]['slr_{}'.format(i)]['C06_Birthp'] for i in range(0,160,10)]
    v_nz_born_13 = [regional_dict[rc]['slr_{}'.format(i)]['C13_Birthp'] for i in range(0,160,10)]
    v_nz_born_18 = [regional_dict[rc]['slr_{}'.format(i)]['C18_Birthp'] for i in range(0,160,10)]
    v_overseas_born_06 = [regional_dict[rc]['slr_{}'.format(i)]['C06_Birt_1'] for i in range(0,160,10)]
    v_overseas_born_13 = [regional_dict[rc]['slr_{}'.format(i)]['C13_Birt_1'] for i in range(0,160,10)]
    v_overseas_born_18 = [regional_dict[rc]['slr_{}'.format(i)]['C18_Birt_1'] for i in range(0,160,10)]
    total_06 = [sum(x) for x in zip(v_nz_born_06, v_overseas_born_06)]
    total_13 = [sum(x) for x in zip(v_nz_born_13, v_overseas_born_13)]
    total_18 = [sum(x) for x in zip(v_nz_born_18, v_overseas_born_18)]
    p_nz_born_06 = [((x/y)*100) for x, y in zip(v_nz_born_06, total_06)]
    p_nz_born_13 = [((x/y)*100) for x, y in zip(v_nz_born_13, total_13)]
    p_nz_born_18 = [((x/y)*100) for x, y in zip(v_nz_born_18, total_18)]
    p_overseas_born_06 = [((x/y)*100) for x, y in zip(v_overseas_born_06, total_06)]
    p_overseas_born_13 = [((x/y)*100) for x, y in zip(v_overseas_born_13, total_13)]
    p_overseas_born_18 = [((x/y)*100) for x, y in zip(v_overseas_born_18, total_18)]
    r_nz_born_06 = [regional_noslr_dict[rc]['C06_Birthp'] for i in range(0, 160, 10)]
    r_nz_born_13 = [regional_noslr_dict[rc]['C13_Birthp'] for i in range(0, 160, 10)]
    r_nz_born_18 = [regional_noslr_dict[rc]['C18_Birthp'] for i in range(0, 160, 10)]
    r_overseas_born_06 = [regional_noslr_dict[rc]['C06_Birt_1'] for i in range(0, 160, 10)]
    r_overseas_born_13 = [regional_noslr_dict[rc]['C13_Birt_1'] for i in range(0, 160, 10)]
    r_overseas_born_18 = [regional_noslr_dict[rc]['C18_Birt_1'] for i in range(0, 160, 10)]
    pc_nz_born_06 = [z-(x/((x+y)/100)) for x, y, z in zip(r_nz_born_06, r_overseas_born_06, p_nz_born_06)]
    pc_nz_born_13 = [z-(x/((x+y)/100)) for x, y, z in zip(r_nz_born_13, r_overseas_born_13, p_nz_born_13)]
    pc_nz_born_18 = [z-(x/((x+y)/100)) for x, y, z in zip(r_nz_born_18, r_overseas_born_18, p_nz_born_18)]
    pc_overseas_born_06 = [z-(x/((x+y)/100)) for x, y, z in zip(r_overseas_born_06, r_overseas_born_06, p_overseas_born_06)]
    pc_overseas_born_13 = [z-(x/((x+y)/100)) for x, y, z in zip(r_overseas_born_13, r_overseas_born_13, p_overseas_born_13)]
    pc_overseas_born_18 = [z-(x/((x+y)/100)) for x, y, z in zip(r_overseas_born_18, r_overseas_born_18, p_overseas_born_18)]
    po_nz_born_06 = [x/(y/100) for x, y in zip(v_nz_born_06, r_nz_born_06)]
    po_nz_born_13 = [x/(y/100) for x, y in zip(v_nz_born_13, r_nz_born_13)]
    po_nz_born_18 = [x/(y/100) for x, y in zip(v_nz_born_18, r_nz_born_18)]
    po_overseas_born_06 = [x/(y/100) for x, y in zip(v_overseas_born_06, r_overseas_born_06)]
    po_overseas_born_13 = [x/(y/100) for x, y in zip(v_overseas_born_13, r_overseas_born_13)]
    po_overseas_born_18 = [x/(y/100) for x, y in zip(v_overseas_born_18, r_overseas_born_18)]
    
    '''nz_born'''
    v_nz_born_dict_time = {}
    p_nz_born_dict_time = {}
    pc_nz_born_dict_time = {}
    po_nz_born_dict_time = {}
    
    if rc == 'otago':
        rc = 'otago   '
    
    v_nz_born_df = pd.DataFrame({'years' : years})
    v_nz_born_df.columns.name = rc
    p_nz_born_df = pd.DataFrame({'years' : years})
    p_nz_born_df.columns.name = rc
    pc_nz_born_df = pd.DataFrame({'years' : years})
    pc_nz_born_df.columns.name = rc
    po_nz_born_df = pd.DataFrame({'years' : years})
    po_nz_born_df.columns.name = rc
    
    for i in range(0, 16, 1):
        v_nz_born_time = []
        v_nz_born_time.append(v_nz_born_06[i])
        v_nz_born_time.append(v_nz_born_13[i])
        v_nz_born_time.append(v_nz_born_18[i])
        v_nz_born_dict_time.update({'slr_{}0'.format(i) : v_nz_born_time})
        p_nz_born_time = []
        p_nz_born_time.append(p_nz_born_06[i])
        p_nz_born_time.append(p_nz_born_13[i])
        p_nz_born_time.append(p_nz_born_18[i])
        p_nz_born_dict_time.update({'slr_{}0'.format(i) : p_nz_born_time})
        pc_nz_born_time = []
        pc_nz_born_time.append(pc_nz_born_06[i])
        pc_nz_born_time.append(pc_nz_born_13[i])
        pc_nz_born_time.append(pc_nz_born_18[i])
        pc_nz_born_dict_time.update({'slr_{}0'.format(i) : pc_nz_born_time})
        po_nz_born_time = []
        po_nz_born_time.append(po_nz_born_06[i])
        po_nz_born_time.append(po_nz_born_13[i])
        po_nz_born_time.append(po_nz_born_18[i])
        po_nz_born_dict_time.update({'slr_{}0'.format(i) : po_nz_born_time})
        if i == 0 or i == 5 or i == 10:
            v_nz_born_df['slr_{}0'.format(i)] = v_nz_born_time
            po_nz_born_df['slr_{}0'.format(i)] = [round(num, 1) for num in po_nz_born_time]
        
        
    '''overseas_born'''
    v_overseas_born_dict_time = {}
    p_overseas_born_dict_time = {}
    pc_overseas_born_dict_time = {}
    po_overseas_born_dict_time = {}
    
    if rc == 'otago':
        rc = 'otago   '
    
    v_overseas_born_df = pd.DataFrame({'years' : years})
    v_overseas_born_df.columns.name = rc
    po_overseas_born_df = pd.DataFrame({'years' : years})
    po_overseas_born_df.columns.name = rc
    
    for i in range(0, 16, 1):
        v_overseas_born_time = []
        v_overseas_born_time.append(v_overseas_born_06[i])
        v_overseas_born_time.append(v_overseas_born_13[i])
        v_overseas_born_time.append(v_overseas_born_18[i])
        v_overseas_born_dict_time.update({'slr_{}0'.format(i) : v_overseas_born_time})
        p_overseas_born_time = []
        p_overseas_born_time.append(p_overseas_born_06[i])
        p_overseas_born_time.append(p_overseas_born_13[i])
        p_overseas_born_time.append(p_overseas_born_18[i])
        p_overseas_born_dict_time.update({'slr_{}0'.format(i) : p_overseas_born_time})
        pc_overseas_born_time = []
        pc_overseas_born_time.append(pc_overseas_born_06[i])
        pc_overseas_born_time.append(pc_overseas_born_13[i])
        pc_overseas_born_time.append(pc_overseas_born_18[i])
        pc_overseas_born_dict_time.update({'slr_{}0'.format(i) : pc_overseas_born_time})
        po_overseas_born_time = []
        po_overseas_born_time.append(po_overseas_born_06[i])
        po_overseas_born_time.append(po_overseas_born_13[i])
        po_overseas_born_time.append(po_overseas_born_18[i])
        po_overseas_born_dict_time.update({'slr_{}0'.format(i) : po_overseas_born_time})
        if i == 0 or i == 5 or i == 10:
            v_overseas_born_df['slr_{}0'.format(i)] = v_overseas_born_time
            po_overseas_born_df['slr_{}0'.format(i)] = [round(num, 1) for num in po_overseas_born_time]
    
    
    '''make all this data useful and orderly'''
    birthplace_dict_time = {'nz_born_value' : v_nz_born_dict_time, 'nz_born_percentage' : p_nz_born_dict_time, 'nz_born_pc' : pc_nz_born_dict_time, 'nz_born_po' : po_nz_born_dict_time, 'overseas_born_value' : v_overseas_born_dict_time, 'overseas_born_percentage' : p_overseas_born_dict_time, 'overseas_born_pc' : pc_overseas_born_dict_time, 'overseas_born_po' : po_overseas_born_dict_time}
    years = [2006, 2013, 2018]
    title_offset = 1.03

    
    ''' plot against time numbers '''
    for i in range(0, 11, 5):
        x = 'slr_'+ str(i) + '0'
        y = "nz_born " + str(i) + "0cm"
        plt.plot(years, birthplace_dict_time['nz_born_value'][x], label=y, color="c")
        plt.annotate(y, (2018, birthplace_dict_time['nz_born_value'][x][2]), textcoords="offset points", xytext=(40,5), fontsize=11, ha='center', color='c')
    for i in range(0, 11, 5):
        x = 'slr_'+ str(i) + '0'
        y = "overseas_born " + str(i) + "0cm"
        plt.plot(years, birthplace_dict_time['overseas_born_value'][x], label=y, color="pink")
        plt.annotate(y, (2018, birthplace_dict_time['overseas_born_value'][x][2]), textcoords="offset points", xytext=(115,0), fontsize=11, ha='center', color='pink')
        plt.xlabel('Year')
        plt.ylabel('Number of people exposed')
        plt.title('Number of each birthplace exposed to sea level rise against time', y=title_offset)
        ax = plt.subplot(111)
        ax.spines["right"].set_visible(False)
        ax.spines["top"].set_visible(False)
    plt.figure(figsize=(10.4, 8))
    plt.show()
    
    
    ''' plot against time  percentages '''
    for i in range(0, 11, 5):
        x = 'slr_'+ str(i) + '0'
        y = "nz_born " + str(i) + "0cm"
        plt.plot(years, birthplace_dict_time['nz_born_percentage'][x], label=y, color="c")
        plt.annotate(y, (2018, birthplace_dict_time['nz_born_percentage'][x][2]), textcoords="offset points", xytext=(40,0), fontsize=11, ha='center', color='c')
    for i in range(0, 11, 5):
        x = 'slr_'+ str(i) + '0'
        y = "overseas_born " + str(i) + "0cm"
        plt.plot(years, birthplace_dict_time['overseas_born_percentage'][x], label=y, color="pink")
        plt.annotate(y, (2018, birthplace_dict_time['overseas_born_percentage'][x][2]), textcoords="offset points", xytext=(40,0), fontsize=11, ha='center', color='pink')
        plt.xlabel('Year')
        plt.ylabel('Percentage of people exposed')
        plt.title('Percentage of each birthplace exposed to sea level rise against time', y=title_offset)
        ax = plt.subplot(111)
        ax.spines["right"].set_visible(False)
        ax.spines["top"].set_visible(False)
    plt.show()
    
    
    ''' plot against time percentage change '''
    for i in range(0, 11, 5):
        x = 'slr_'+ str(i) + '0'
        y = "nz_born " + str(i) + "0cm"
        plt.plot(years, birthplace_dict_time['nz_born_pc'][x], label=y, color="c")
        plt.annotate(y, (2018, birthplace_dict_time['nz_born_pc'][x][2]), textcoords="offset points", xytext=(40,0), fontsize=11, ha='center', color='c')
    for i in range(0, 11, 5):
        x = 'slr_'+ str(i) + '0'
        y = "overseas_born " + str(i) + "0cm"
        plt.plot(years, birthplace_dict_time['overseas_born_pc'][x], label=y, color="pink")
        plt.annotate(y, (2018, birthplace_dict_time['overseas_born_pc'][x][2]), textcoords="offset points", xytext=(40,0), fontsize=11, ha='center', color='pink')
        plt.xlabel('Year')
        plt.ylabel('Percentage change of people exposed')
        plt.title('Percentage change of each birthplace exposed to sea level rise against time', y=title_offset)
        ax = plt.subplot(111)
        ax.spines["right"].set_visible(False)
        ax.spines["top"].set_visible(False)
    plt.show()
    
    
    '''plot slr increase percentage of overall population'''
    for i in range(0, 11, 5):
        x = 'slr_'+ str(i) + '0'
        y = "nz_born " + str(i) + "0cm"
        plt.plot(years, birthplace_dict_time['nz_born_po'][x], label=y, color="c")
        plt.annotate(y, (2018, birthplace_dict_time['nz_born_po'][x][2]), textcoords="offset points", xytext=(40,5), fontsize=11, ha='center', color='c')
    for i in range(0, 11, 5):
        x = 'slr_'+ str(i) + '0'
        y = "overseas_born " + str(i) + "0cm"
        plt.plot(years, birthplace_dict_time['overseas_born_po'][x], label=y, color="pink")
        plt.annotate(y, (2018, birthplace_dict_time['overseas_born_po'][x][2]), textcoords="offset points", xytext=(115,0), fontsize=11, ha='center', color='pink')
        plt.xlabel('Year')
        plt.ylabel('Percentage of overall population exposed')
        plt.title('Percentage of overall population of each birthplace exposed to sea level rise against time', y=title_offset)
        ax = plt.subplot(111)
        ax.spines["right"].set_visible(False)
        ax.spines["top"].set_visible(False)
    plt.show()
    

    '''values and percentage of overall in table'''
    v_overseas_born_all_df = pd.concat([v_nz_born_df, v_nz_born_df ], axis=1)
    po_overseas_born_all_df = pd.concat([po_overseas_born_df, po_overseas_born_df ], axis=1)
    print(v_overseas_born_all_df)
    print(po_overseas_born_all_df)

# %%
'''import files and clip, pd.set_option('display.max_rows', 150)'''

census = gpd.read_file('data/nz_census/2018-census-individual-part-1-total-new-zealand-by-statistic.shp')
regions = gpd.read_file('data/boundaries/regional_boundaries/REGC2017_HD_Clipped.shp')
city_b = gpd.read_file('data/boundaries/city/UA2017_HD_Clipped.shp')
suburb_b = gpd.read_file('data/boundaries/suburb/TASUB2017_HD_Clipped.shp')

auckland_b = regions.iloc[1,4]
wellington_b = city_b.iloc[19,4]
christchurch_b = city_b.iloc[21,4]
dunedin_b = city_b.iloc[22,4]
tauranga_b = city_b.iloc[8,4]

for i in range(0, 5, 1):
    

chch_sub_dict = {}
for i in range(0, 3, 1):
    no = i + 82
    key = suburb_b[no, 1]
    chch_sub_dict.update
    
harewood = suburb_b[82, 4]
waimari = suburb_b[83, 4]
papanui = suburb_b[84, 4]
fendalton = suburb_b[85, 4]
innes = suburb_b[86, 4]
burwood = suburb_b[87, 4]
coastal = suburb_b[88, 4]
hornbyu = suburb_b[89, 4]
halswel = suburb_b[90, 4]
riccarton = suburb_b[91, 4]
spreydon = suburb_b[92, 4]
central = suburb_b[93, 4]
cashmere = suburb_b[94, 4]
linwood = suburb_b[95, 4]
heathcote = suburb_b[96, 4]
lyttleton = suburb_b[97, 4]

# %%
#time progression - maori descent 

for rc in rc_names:
    print(rc)
    df_years = pd.DataFrame({'years' : years})
    '''collate relevent data'''
    v_maori_decent_06 = [regional_dict[rc]['slr_{}'.format(i)]['C06_Maori_'] for i in range(0,160,10)]
    v_maori_decent_13 = [regional_dict[rc]['slr_{}'.format(i)]['C13_Maori_'] for i in range(0,160,10)]
    v_maori_decent_18 = [regional_dict[rc]['slr_{}'.format(i)]['C18_Maori_'] for i in range(0,160,10)]
    v_no_maori_decent_06 = [regional_dict[rc]['slr_{}'.format(i)]['C06_Maor_1'] for i in range(0,160,10)]
    v_no_maori_decent_13 = [regional_dict[rc]['slr_{}'.format(i)]['C13_Maor_1'] for i in range(0,160,10)]
    v_no_maori_decent_18 = [regional_dict[rc]['slr_{}'.format(i)]['C18_Maor_1'] for i in range(0,160,10)]
    total_06 = [sum(x) for x in zip(v_maori_decent_06, v_no_maori_decent_06)]
    total_13 = [sum(x) for x in zip(v_maori_decent_13, v_no_maori_decent_13)]
    total_18 = [sum(x) for x in zip(v_maori_decent_18, v_no_maori_decent_18)]
    p_maori_decent_06 = [((x/y)*100) for x, y in zip(v_maori_decent_06, total_06)]
    p_maori_decent_13 = [((x/y)*100) for x, y in zip(v_maori_decent_13, total_13)]
    p_maori_decent_18 = [((x/y)*100) for x, y in zip(v_maori_decent_18, total_18)]
    p_no_maori_decent_06 = [((x/y)*100) for x, y in zip(v_no_maori_decent_06, total_06)]
    p_no_maori_decent_13 = [((x/y)*100) for x, y in zip(v_no_maori_decent_13, total_13)]
    p_no_maori_decent_18 = [((x/y)*100) for x, y in zip(v_no_maori_decent_18, total_18)]
    r_maori_decent_06 = [regional_noslr_dict[rc]['C06_Maori_'] for i in range(0, 160, 10)]
    r_maori_decent_13 = [regional_noslr_dict[rc]['C13_Maori_'] for i in range(0, 160, 10)]
    r_maori_decent_18 = [regional_noslr_dict[rc]['C18_Maori_'] for i in range(0, 160, 10)]
    r_no_maori_decent_06 = [regional_noslr_dict[rc]['C06_Maor_1'] for i in range(0, 160, 10)]
    r_no_maori_decent_13 = [regional_noslr_dict[rc]['C13_Maor_1'] for i in range(0, 160, 10)]
    r_no_maori_decent_18 = [regional_noslr_dict[rc]['C18_Maor_1'] for i in range(0, 160, 10)]
    pc_maori_decent_06 = [z-(x/((x+y)/100)) for x, y, z in zip(r_maori_decent_06, r_no_maori_decent_06, p_maori_decent_06)]
    pc_maori_decent_13 = [z-(x/((x+y)/100)) for x, y, z in zip(r_maori_decent_13, r_no_maori_decent_13, p_maori_decent_13)]
    pc_maori_decent_18 = [z-(x/((x+y)/100)) for x, y, z in zip(r_maori_decent_18, r_no_maori_decent_18, p_maori_decent_18)]
    pc_no_maori_decent_06 = [z-(x/((x+y)/100)) for x, y, z in zip(r_no_maori_decent_06, r_no_maori_decent_06, p_no_maori_decent_06)]
    pc_no_maori_decent_13 = [z-(x/((x+y)/100)) for x, y, z in zip(r_no_maori_decent_13, r_no_maori_decent_13, p_no_maori_decent_13)]
    pc_no_maori_decent_18 = [z-(x/((x+y)/100)) for x, y, z in zip(r_no_maori_decent_18, r_no_maori_decent_18, p_no_maori_decent_18)]
    po_maori_decent_06 = [x/(y/100) for x, y in zip(v_maori_decent_06, r_maori_decent_06)]
    po_maori_decent_13 = [x/(y/100) for x, y in zip(v_maori_decent_13, r_maori_decent_13)]
    po_maori_decent_18 = [x/(y/100) for x, y in zip(v_maori_decent_18, r_maori_decent_18)]
    po_no_maori_decent_06 = [x/(y/100) for x, y in zip(v_no_maori_decent_06, r_no_maori_decent_06)]
    po_no_maori_decent_13 = [x/(y/100) for x, y in zip(v_no_maori_decent_13, r_no_maori_decent_13)]
    po_no_maori_decent_18 = [x/(y/100) for x, y in zip(v_no_maori_decent_18, r_no_maori_decent_18)]
    
    '''maori_decent'''
    v_maori_decent_dict_time = {}
    p_maori_decent_dict_time = {}
    pc_maori_decent_dict_time = {}
    po_maori_decent_dict_time = {}
    
    if rc == 'otago':
        rc = 'otago   '
    
    v_maori_decent_df = pd.DataFrame({'years' : years})
    v_maori_decent_df.columns.name = rc
    p_maori_decent_df = pd.DataFrame({'years' : years})
    p_maori_decent_df.columns.name = rc
    pc_maori_decent_df = pd.DataFrame({'years' : years})
    pc_maori_decent_df.columns.name = rc
    po_maori_decent_df = pd.DataFrame({'years' : years})
    po_maori_decent_df.columns.name = rc
    
    for i in range(0, 16, 1):
        v_maori_decent_time = []
        v_maori_decent_time.append(v_maori_decent_06[i])
        v_maori_decent_time.append(v_maori_decent_13[i])
        v_maori_decent_time.append(v_maori_decent_18[i])
        v_maori_decent_dict_time.update({'slr_{}0'.format(i) : v_maori_decent_time})
        p_maori_decent_time = []
        p_maori_decent_time.append(p_maori_decent_06[i])
        p_maori_decent_time.append(p_maori_decent_13[i])
        p_maori_decent_time.append(p_maori_decent_18[i])
        p_maori_decent_dict_time.update({'slr_{}0'.format(i) : p_maori_decent_time})
        pc_maori_decent_time = []
        pc_maori_decent_time.append(pc_maori_decent_06[i])
        pc_maori_decent_time.append(pc_maori_decent_13[i])
        pc_maori_decent_time.append(pc_maori_decent_18[i])
        pc_maori_decent_dict_time.update({'slr_{}0'.format(i) : pc_maori_decent_time})
        po_maori_decent_time = []
        po_maori_decent_time.append(po_maori_decent_06[i])
        po_maori_decent_time.append(po_maori_decent_13[i])
        po_maori_decent_time.append(po_maori_decent_18[i])
        po_maori_decent_dict_time.update({'slr_{}0'.format(i) : po_maori_decent_time})
        if i == 0 or i == 5 or i == 10:
            v_maori_decent_df['slr_{}0'.format(i)] = v_maori_decent_time
            po_maori_decent_df['slr_{}0'.format(i)] = [round(num, 1) for num in po_maori_decent_time]
        
        
    '''no_maori_decent'''
    v_no_maori_decent_dict_time = {}
    p_no_maori_decent_dict_time = {}
    pc_no_maori_decent_dict_time = {}
    po_no_maori_decent_dict_time = {}
    
    if rc == 'otago':
        rc = 'otago   '
    
    v_no_maori_decent_df = pd.DataFrame({'years' : years})
    v_no_maori_decent_df.columns.name = rc
    po_no_maori_decent_df = pd.DataFrame({'years' : years})
    po_no_maori_decent_df.columns.name = rc
    
    for i in range(0, 16, 1):
        v_no_maori_decent_time = []
        v_no_maori_decent_time.append(v_no_maori_decent_06[i])
        v_no_maori_decent_time.append(v_no_maori_decent_13[i])
        v_no_maori_decent_time.append(v_no_maori_decent_18[i])
        v_no_maori_decent_dict_time.update({'slr_{}0'.format(i) : v_no_maori_decent_time})
        p_no_maori_decent_time = []
        p_no_maori_decent_time.append(p_no_maori_decent_06[i])
        p_no_maori_decent_time.append(p_no_maori_decent_13[i])
        p_no_maori_decent_time.append(p_no_maori_decent_18[i])
        p_no_maori_decent_dict_time.update({'slr_{}0'.format(i) : p_no_maori_decent_time})
        pc_no_maori_decent_time = []
        pc_no_maori_decent_time.append(pc_no_maori_decent_06[i])
        pc_no_maori_decent_time.append(pc_no_maori_decent_13[i])
        pc_no_maori_decent_time.append(pc_no_maori_decent_18[i])
        pc_no_maori_decent_dict_time.update({'slr_{}0'.format(i) : pc_no_maori_decent_time})
        po_no_maori_decent_time = []
        po_no_maori_decent_time.append(po_no_maori_decent_06[i])
        po_no_maori_decent_time.append(po_no_maori_decent_13[i])
        po_no_maori_decent_time.append(po_no_maori_decent_18[i])
        po_no_maori_decent_dict_time.update({'slr_{}0'.format(i) : po_no_maori_decent_time})
        if i == 0 or i == 5 or i == 10:
            v_no_maori_decent_df['slr_{}0'.format(i)] = v_no_maori_decent_time
            po_no_maori_decent_df['slr_{}0'.format(i)] = [round(num, 1) for num in po_no_maori_decent_time]
    
    
    '''make all this data useful and orderly'''
    Maoridescent_dict_time = {'maori_decent_value' : v_maori_decent_dict_time, 'maori_decent_percentage' : p_maori_decent_dict_time, 'maori_decent_pc' : pc_maori_decent_dict_time, 'maori_decent_po' : po_maori_decent_dict_time, 'no_maori_decent_value' : v_no_maori_decent_dict_time, 'no_maori_decent_percentage' : p_no_maori_decent_dict_time, 'no_maori_decent_pc' : pc_no_maori_decent_dict_time, 'no_maori_decent_po' : po_no_maori_decent_dict_time}
    years = [2006, 2013, 2018]
    title_offset = 1.03

    
    ''' plot against time numbers '''
    for i in range(0, 11, 5):
        x = 'slr_'+ str(i) + '0'
        y = "maori_decent " + str(i) + "0cm"
        plt.plot(years, Maoridescent_dict_time['maori_decent_value'][x], label=y, color="c")
        plt.annotate(y, (2018, Maoridescent_dict_time['maori_decent_value'][x][2]), textcoords="offset points", xytext=(40,5), fontsize=11, ha='center', color='c')
    for i in range(0, 11, 5):
        x = 'slr_'+ str(i) + '0'
        y = "no_maori_decent " + str(i) + "0cm"
        plt.plot(years, Maoridescent_dict_time['no_maori_decent_value'][x], label=y, color="pink")
        plt.annotate(y, (2018, Maoridescent_dict_time['no_maori_decent_value'][x][2]), textcoords="offset points", xytext=(115,0), fontsize=11, ha='center', color='pink')
        plt.xlabel('Year')
        plt.ylabel('Number of people exposed')
        plt.title('Number of each Maoridescent exposed to sea level rise against time', y=title_offset)
        ax = plt.subplot(111)
        ax.spines["right"].set_visible(False)
        ax.spines["top"].set_visible(False)
    plt.figure(figsize=(10.4, 8))
    plt.show()
    
    
    ''' plot against time  percentages '''
    for i in range(0, 11, 5):
        x = 'slr_'+ str(i) + '0'
        y = "maori_decent " + str(i) + "0cm"
        plt.plot(years, Maoridescent_dict_time['maori_decent_percentage'][x], label=y, color="c")
        plt.annotate(y, (2018, Maoridescent_dict_time['maori_decent_percentage'][x][2]), textcoords="offset points", xytext=(40,0), fontsize=11, ha='center', color='c')
    for i in range(0, 11, 5):
        x = 'slr_'+ str(i) + '0'
        y = "no_maori_decent " + str(i) + "0cm"
        plt.plot(years, Maoridescent_dict_time['no_maori_decent_percentage'][x], label=y, color="pink")
        plt.annotate(y, (2018, Maoridescent_dict_time['no_maori_decent_percentage'][x][2]), textcoords="offset points", xytext=(40,0), fontsize=11, ha='center', color='pink')
        plt.xlabel('Year')
        plt.ylabel('Percentage of people exposed')
        plt.title('Percentage of each Maoridescent exposed to sea level rise against time', y=title_offset)
        ax = plt.subplot(111)
        ax.spines["right"].set_visible(False)
        ax.spines["top"].set_visible(False)
    plt.show()
    
    
    ''' plot against time percentage change '''
    for i in range(0, 11, 5):
        x = 'slr_'+ str(i) + '0'
        y = "maori_decent " + str(i) + "0cm"
        plt.plot(years, Maoridescent_dict_time['maori_decent_pc'][x], label=y, color="c")
        plt.annotate(y, (2018, Maoridescent_dict_time['maori_decent_pc'][x][2]), textcoords="offset points", xytext=(40,0), fontsize=11, ha='center', color='c')
    for i in range(0, 11, 5):
        x = 'slr_'+ str(i) + '0'
        y = "no_maori_decent " + str(i) + "0cm"
        plt.plot(years, Maoridescent_dict_time['no_maori_decent_pc'][x], label=y, color="pink")
        plt.annotate(y, (2018, Maoridescent_dict_time['no_maori_decent_pc'][x][2]), textcoords="offset points", xytext=(40,0), fontsize=11, ha='center', color='pink')
        plt.xlabel('Year')
        plt.ylabel('Percentage change of people exposed')
        plt.title('Percentage change of each Maoridescent exposed to sea level rise against time', y=title_offset)
        ax = plt.subplot(111)
        ax.spines["right"].set_visible(False)
        ax.spines["top"].set_visible(False)
    plt.show()
    
    
    '''plot slr increase percentage of overall population'''
    for i in range(0, 11, 5):
        x = 'slr_'+ str(i) + '0'
        y = "maori_decent " + str(i) + "0cm"
        plt.plot(years, Maoridescent_dict_time['maori_decent_po'][x], label=y, color="c")
        plt.annotate(y, (2018, Maoridescent_dict_time['maori_decent_po'][x][2]), textcoords="offset points", xytext=(40,5), fontsize=11, ha='center', color='c')
    for i in range(0, 11, 5):
        x = 'slr_'+ str(i) + '0'
        y = "no_maori_decent " + str(i) + "0cm"
        plt.plot(years, Maoridescent_dict_time['no_maori_decent_po'][x], label=y, color="pink")
        plt.annotate(y, (2018, Maoridescent_dict_time['no_maori_decent_po'][x][2]), textcoords="offset points", xytext=(115,0), fontsize=11, ha='center', color='pink')
        plt.xlabel('Year')
        plt.ylabel('Percentage of overall population exposed')
        plt.title('Percentage of overall population of each Maoridescent exposed to sea level rise against time', y=title_offset)
        ax = plt.subplot(111)
        ax.spines["right"].set_visible(False)
        ax.spines["top"].set_visible(False)
    plt.show()
    

    '''values and percentage of overall in table'''
    maori_decent_all_df = pd.concat([v_maori_decent_df, po_maori_decent_df ], axis=1)
    no_maori_decent_all_df = pd.concat([v_no_maori_decent_df, po_no_maori_decent_df ], axis=1)
    print(maori_decent_all_df)
    print(maori_decent_all_df)

# %%
'''turning data into pandas'''

for rc in rc_names:
    print(rc)
    '''collate relevent data'''
    v_female_06 = [regional_dict[rc]['slr_{}'.format(i)]['C06_Sex_Fe'] for i in range(0,160,10)]
    v_female_13 = [regional_dict[rc]['slr_{}'.format(i)]['C13_Sex_Fe'] for i in range(0,160,10)]
    v_female_18 = [regional_dict[rc]['slr_{}'.format(i)]['C18_Sex_Fe'] for i in range(0,160,10)]
    v_male_06 = [regional_dict[rc]['slr_{}'.format(i)]['C06_Sex_Ma'] for i in range(0,160,10)]
    v_male_13 = [regional_dict[rc]['slr_{}'.format(i)]['C13_Sex_Ma'] for i in range(0,160,10)]
    v_male_18 = [regional_dict[rc]['slr_{}'.format(i)]['C18_Sex_Ma'] for i in range(0,160,10)]
    total_06 = [sum(x) for x in zip(v_female_06, v_male_06)]
    total_13 = [sum(x) for x in zip(v_female_13, v_male_13)]
    total_18 = [sum(x) for x in zip(v_female_18, v_male_18)]
    p_female_06 = [((x/y)*100) for x, y in zip(v_female_06, total_06)]
    p_female_13 = [((x/y)*100) for x, y in zip(v_female_13, total_13)]
    p_female_18 = [((x/y)*100) for x, y in zip(v_female_18, total_18)]
    p_male_06 = [((x/y)*100) for x, y in zip(v_male_06, total_06)]
    p_male_13 = [((x/y)*100) for x, y in zip(v_male_13, total_13)]
    p_male_18 = [((x/y)*100) for x, y in zip(v_male_18, total_18)]
    r_female_06 = [regional_noslr_dict[rc]['C06_Sex_Fe'] for i in range(0, 160, 10)]
    r_female_13 = [regional_noslr_dict[rc]['C13_Sex_Fe'] for i in range(0, 160, 10)]
    r_female_18 = [regional_noslr_dict[rc]['C18_Sex_Fe'] for i in range(0, 160, 10)]
    r_male_06 = [regional_noslr_dict[rc]['C06_Sex_Ma'] for i in range(0, 160, 10)]
    r_male_13 = [regional_noslr_dict[rc]['C13_Sex_Ma'] for i in range(0, 160, 10)]
    r_male_18 = [regional_noslr_dict[rc]['C18_Sex_Ma'] for i in range(0, 160, 10)]
    pc_female_06 = [z-(x/((x+y)/100)) for x, y, z in zip(r_female_06, r_male_06, p_female_06)]
    pc_female_13 = [z-(x/((x+y)/100)) for x, y, z in zip(r_female_13, r_male_13, p_female_13)]
    pc_female_18 = [z-(x/((x+y)/100)) for x, y, z in zip(r_female_18, r_male_18, p_female_18)]
    pc_male_06 = [z-(x/((x+y)/100)) for x, y, z in zip(r_male_06, r_male_06, p_male_06)]
    pc_male_13 = [z-(x/((x+y)/100)) for x, y, z in zip(r_male_13, r_male_13, p_male_13)]
    pc_male_18 = [z-(x/((x+y)/100)) for x, y, z in zip(r_male_18, r_male_18, p_male_18)]
    po_female_06 = [x/(y/100) for x, y in zip(v_female_06, r_female_06)]
    po_female_13 = [x/(y/100) for x, y in zip(v_female_13, r_female_13)]
    po_female_18 = [x/(y/100) for x, y in zip(v_female_18, r_female_18)]
    po_male_06 = [x/(y/100) for x, y in zip(v_male_06, r_male_06)]
    po_male_13 = [x/(y/100) for x, y in zip(v_male_13, r_male_13)]
    po_male_18 = [x/(y/100) for x, y in zip(v_male_18, r_male_18)]
                     
    '''female'''
    v_fem_dict_time = {}
    p_fem_dict_time = {}
    pc_fem_dict_time = {}
    po_fem_dict_time = {}

# %%
'''colour pallette 1'''

tableau20 = [(31, 119, 180), (174, 199, 232), (255, 127, 14), (255, 187, 120),    
         (44, 160, 44), (152, 223, 138), (214, 39, 40), (255, 152, 150),    
         (148, 103, 189)]

for i in range(len(tableau20)):  #Scale the RGB values to the [0, 1] range, which is the format matplotlib accepts.  
    r, g, b = tableau20[i]    
    tableau20[i] = (r / 255., g / 255., b / 255.)

color=tableau20[i]

# %%
'''colour palette 2'''

tableau20 = [(31, 119, 180), (174, 199, 232), (255, 127, 14), (255, 187, 120),    
             (44, 160, 44), (152, 223, 138), (214, 39, 40), (255, 152, 150),    
             (148, 103, 189), (197, 176, 213), (140, 86, 75), (196, 156, 148),    
             (227, 119, 194), (247, 182, 210), (127, 127, 127), (199, 199, 199),    
             (188, 189, 34), (219, 219, 141), (23, 190, 207), (158, 218, 229)]     

for i in range(len(tableau20)):    
    r, g, b = tableau20[i]    
    tableau20[i] = (r / 255., g / 255., b / 255.) 
    
plt.figure(figsize=(12, 14))    

ax = plt.subplot(111)    
ax.spines["top"].set_visible(False)    
ax.spines["bottom"].set_visible(False)    
ax.spines["right"].set_visible(False)    
ax.spines["left"].set_visible(False)

ax.get_xaxis().tick_bottom()    
ax.get_yaxis().tick_left()   
    
plt.ylim(16.5, 22.5)    
plt.xlim(0, 150)

plt.yticks(range(0, 91, 10), [str(x) + "%" for x in range(0, 91, 10)], fontsize=14)    
plt.xticks(fontsize=14) 

for y in range(10, 91, 10):    
    plt.plot(range(0, 150), [y] * len(range(1968, 2012)), "--", lw=0.5, color="black", alpha=0.3)
    
plt.tick_params(axis="both", which="both", bottom="off", top="off",    
                labelbottom="on", left="off", right="off", labelleft="on")  

plt.plot(slr, po_female_06, label="female 06")
plt.plot(slr, po_female_13, label="female 13")
plt.plot(slr, po_female_18, label="female 18")
plt.plot(slr, po_male_06, label="male 06")
plt.plot(slr, po_male_13, label="male 13")
plt.plot(slr, po_male_18, label="male 18")

# %%
'''time to run code'''
end = timer()
x = round(((end - start)/60), 2)
print("The code takes " + str(x) + " minutes to run")

# %%
'''''creating dictionaries ready for later on'''

'''create dictionary islands'''

north_dict = {}
rc_names_north  = ['northland', 'auckland', 'waikato', 'bay_of_plenty', 'gisborne','hawkes_bay','taranaki','manawatu_wanganui']
rc_names_abrv_north = ['northland', 'auckland', 'waikato', 'bay_of_plenty', 'gisborne','hawkes_bay','taranaki','manawatu_wanganui']
south_dict = {}
rc_names_south  = ['west_coast','canterbury','otago','southland','tasman','nelson','marlborough']  
rc_names_abrv_south = ['west_coast','canterbury','otago','southland','tasman','nelson','marlborough']
        
for eslr in range(0,160,10):
    slr_list = []
    for rc in range(0,9,1):
        regional_name = rc_names_north[rc]
        regional_name_abrv = rc_names_abrv_north[rc]
        slr_data = gpd.read_file('data/clipped_census/'+ regional_name + '/' + regional_name_abrv + '_aep1pct_{}.shp'.format(eslr))
        slr_data = slr_data.replace(['C', -999, -998, '0', '..', 'Mainland'], 0) 
        slr_list.append(slr_data)
    north_slr_list = pd.concat(slr_list)
    north_slr_list.to_csv('results/north/slr_{}.csv'.format(eslr))
    north_dict.update({'slr_{}'.format(eslr) : north_slr_list}) 

        
for eslr in range(0,160,10):
    slr_list = []
    for rc in range(0,7,1):
        regional_name = rc_names_south[rc]
        regional_name_abrv = rc_names_abrv_south[rc]
        slr_data = gpd.read_file('data/clipped_census/'+ regional_nameN + '/' + regional_name_abrv + '_aep1pct_{}.shp'.format(eslr))
        slr_data = slr_data.replace(['C', -999, -998, '0', '..', 'Mainland'], 0) 
        slr_list.append(slr_data)
    south_slr_list = pd.concat(slr_list)
    south_slr_list.to_csv('results/south/slr_{}.csv'.format(eslr))
    south_dict.update({'slr_{}'.format(eslr) : south_slr_list})

# %%
'''nice plotting for later on'''

for rc in rc_names:
    print(rc)
    '''collate relevent data'''
    v_female_06 = [regional_dict[rc]['slr_{}'.format(i)]['C06_Sex_Fe'] for i in range(0,160,10)]
    v_female_13 = [regional_dict[rc]['slr_{}'.format(i)]['C13_Sex_Fe'] for i in range(0,160,10)]
    v_female_18 = [regional_dict[rc]['slr_{}'.format(i)]['C18_Sex_Fe'] for i in range(0,160,10)]
    v_male_06 = [regional_dict[rc]['slr_{}'.format(i)]['C06_Sex_Ma'] for i in range(0,160,10)]
    v_male_13 = [regional_dict[rc]['slr_{}'.format(i)]['C13_Sex_Ma'] for i in range(0,160,10)]
    v_male_18 = [regional_dict[rc]['slr_{}'.format(i)]['C18_Sex_Ma'] for i in range(0,160,10)]
    
    '''female'''
    v_fem_dict_time = {}
    p_fem_dict_time = {}
    pc_fem_dict_time = {}
    po_fem_dict_time = {}
    
    for i in range(0, 16, 1):
        v_fem_time = []
        v_fem_time.append(v_female_06[i])
        v_fem_time.append(v_female_13[i])
        v_fem_time.append(v_female_18[i])
        v_fem_dict_time.update({'slr_{}0'.format(i) : v_fem_time})
        
    ''' plot against time numbers '''

    plt.plot(years, gender_dict_time['female_value']['slr_150'], label="female 150cm", color="yellow")
    ax = plt.subplot(111)    
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)    
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.get_xaxis().tick_bottom()    
    ax.get_yaxis().tick_left()
    plt.yticks(fontsize=12)    
    plt.xticks(fontsize=12)  
    for y in range(22200, 23050,100):    
        plt.plot(range(2006, 2019), [y] * len(range(2006, 2019)), "--", lw=1, color="black", alpha=0.1)    
    plt.xlabel('Year')
    plt.ylabel('Number of people exposed')
    plt.title('Number of each gender exposed to sea level rise through time', y=1.08)
    label = 'fem 150'  
    
    plt.annotate(label, (2018, gender_dict_time['female_value']['slr_150'][2]), textcoords="offset points", xytext=(30,0), fontsize=11, ha='center')
    plt.show()
    

    
    plt.subplots_adjust(right=1.1)

# %%
'''regional_noslr_dict = {'northland': northland_total, 'auckland' : auckland_total, 'waikato': waikato_total, 'bay_of_plenty': bayofplenty_area, 'gisborne' : gisborne_total,'hawkes_bay' : hawkesbay_total,'taranaki' : taranaki_total,'manawatu_wanganui' : wanganui_total, 'wellington' : wellington_total, 'west_coast': westcoast_total,'canterbury': canturbury_total,'otago': otago_total,'southland' : southland_total,'tasman': tasman_total,'nelson': nelson_total,'marlborough' : marlbourough_total}'''

# %%
'''clippping. code '''


chchsub_noslr_dict = {}
chchsub_area_dict = {}

for i in range(0, 2, 1):
    no = i + 82
    key = suburb_b.iloc[no, 1]
    info = gpd.read_file('results/sub_noslr/' + key + '.csv')
    chchsub_noslr_dict.update({key : sub_clip}
                              
                              
    area = suburb_b.iloc[no, 4]
    chchsub_area_dict.update({key:area})
    sub_clip = gpd.clip(census, area)
    sub_clip = sub_clip.replace(['C', -999, -998, '0', '..', 'Mainland', 'Inlet', 'Oceanic', 'Island'], 0)
    sub_clip.to_csv('results/sub_noslr/' + key + '.csv')
    chchsub_noslr_dict.update({key : sub_clip})
